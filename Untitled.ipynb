# %%
import pandas as pd
df = pd.read_csv('bs_CDP_rep.csv')

# %%
df['cdpcoupyear'] = 0.0

# %%
df['cdpcoupyear'] =
# Out:
#       Unnamed: 0  cowcode                   country  year  incidencev412  \
# 0              1        2  United States of America  1950            0.0
# 1              2        2  United States of America  1951            0.0
# 2              3        2  United States of America  1952            0.0
# 3              4        2  United States of America  1953            0.0
# 4              5        2  United States of America  1954            0.0
# 5              6        2  United States of America  1955            0.0
# 6              7        2  United States of America  1956            0.0
# 7              8        2  United States of America  1957            0.0
# 8              9        2  United States of America  1958            0.0
# 9             10        2  United States of America  1959            0.0
# 10            11        2  United States of America  1960            0.0
# 11            12        2  United States of America  1961            0.0
# ...
