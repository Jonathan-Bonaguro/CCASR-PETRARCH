# %% [markdown]
# # CoreNLP Parsing with NLTK Wrapper
#
# <br>
# This utilizes the NLTK Wrapper for CoreNLP in order to parse sentences from BBN/ACCENT to identify additionally verbs to add to PETRARCH Dictionaries to increase precision and Recall
# <br>
# <br>
# Setup Environment

# %%
from nltk.parse.corenlp import CoreNLPServer
from nltk.parse.corenlp import CoreNLPDependencyParser
from nltk.parse import CoreNLPParser

import pandas as pd

import pprint
import nltk

from nltk.tree import *
from IPython.display import display

# %% [markdown]
# ### Server Terminal > cd $CORENLP_HOME
# <br>
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -annotators "tokenize,ssplit,pos,lemma,parse,sentiment" -port 9000 -timeout 30000
# <br>
# <br>
# Connect parser to server running CoreNLP

# %%
parser = CoreNLPParser('http://localhost:9000')
depr = CoreNLPDependencyParser('http://localhost:9000')

# %% [markdown]
# # NYTBatch50 Accent
# #### Read in NYTbatch50 BBN/ACCENT DATA, trim to CAMEO 145, and create a subset of events to test

# %%
extract = pd.read_csv('Data/nytextract.csv')
protest_violent = extract[extract.code == 145].reset_index()
small = protest_violent.head()
small
# Out:
#    index       aid  code                                               text  \
# 0    240  22338793   145  \n     Yesterday the news agency reported that...
# 1    241  22339503   145  "Thirty-four men arrested late last night were...
# 2    242  22395783   145  "In the worst outbreak of street violence in 1...
# 3    243  22398252   145  Paris policemen and leftist extremists clash a...
# 4    244  22407123   145  Violence occurred through most of the day, des...
#
#    bad
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %% [markdown]
# #### Create regular sentence parser: input data and column

# %%
def core_parser(df, col):
    parse = []
    i = ""
    for i in range(len(df)):
        parse.append(i)
        parse[i] = next(parser.raw_parse(df[col].iloc[i]))
    return parse

# %% [markdown]
# #### Run core_parser with small batch data

# %%
# %time protest_violent['parsed'] = core_parser(protest_violent, 'text')
# Out:
# CPU times: user 110 ms, sys: 9.06 ms, total: 119 ms
# Wall time: 31.3 s

# %% [markdown]
# #### To view each parse-tree, index new column starting at 0

# %%
protest_violent['parsed'].iloc[0]
# Out:
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n']), Tree('NN', ['Yesterday'])]), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['news']), Tree('NN', ['agency'])])]), Tree('VP', [Tree('VBD', ['reported']), Tree('SBAR', [Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP', [Tree('CD', ['three']), Tree('NNS', ['people'])]), Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['been']), Tree('VP', [Tree('VBN', ['killed']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NNS', ['clashes'])]), Tree('PP', [Tree('IN', ['between']), Tree('NP', [Tree('NNS', ['demonstrators'])])])]), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Assam'])])])])])])])])])])]), Tree('CC', ['and']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP', [Tree('QP', [Tree('JJR', ['more']), Tree('IN', ['than']), Tree('CD', ['2,000'])])]), Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['been']), Tree('VP', [Tree('VBN', ['arrested'])])])])])])])]), Tree('.', ['.'])])])

# %% [markdown]
# #### Create dependency sentence parser: input data and column

# %%
def dep_parser(df, col):
    dep = []
    i = ""
    for i in range(len(df)):
        dep.append(i)
        dep[i] = next(depr.raw_parse(df[col].iloc[i]))
    return dep

# %% [markdown]
# #### Run dep_parser with small batch test data

# %%
# %time protest_violent["dep"] = dep_parser(protest_violent, 'text')
# Out:
# CPU times: user 116 ms, sys: 12.2 ms, total: 129 ms
# Wall time: 2.07 s

# %% [markdown]
# #### To view each dependency parse-tree, index new column starting at 0

# %%
protest_violent["dep"].iloc[0]
# Out:
# <DependencyGraph with 32 nodes>

# %% [markdown]
# #### To view both trees simultaneously, use function 'easy_read' with three arguments (dataframe, index number) (this is provided you use the same naming scheme I used, but easy to change)

# %%
def easy_read(corp, index_num):
    display(corp['parsed'].iloc[index_num])
    display(corp['dep'].iloc[index_num])
    display("Text = " + corp.iloc[index_num].loc['text'])
    display("Code = " + str(corp.iloc[index_num].loc['code']))

# %%
easy_read(nyt, nyt_dep, protest_violent, 24, 'text')

# %%
protest_violent

# %% [markdown]
# # NYTbd Sample 14-18
# Read in data

# %%
sample1418 = pd.read_csv("Data/ACCENT NYTbd sample 14 18.csv")

# %%
# Trim to Root Code 18
assault = sample1418[sample1418["root_code"] == 18].reset_index().drop(['index'], axis = 1)

# %%
# %time assault['parsed'] = core_parser(assault, 'text')
# Out:
# CPU times: user 332 ms, sys: 56.4 ms, total: 389 ms
# Wall time: 2min 14s

# %%
# %time assault['dep'] = dep_parser(assault, 'text')
# Out:
# CPU times: user 332 ms, sys: 31.6 ms, total: 363 ms
# Wall time: 17.2 s

# %% [markdown]
# # Look at PETRACH and ACCENT 14_18

# %%
petrarch1418 = pd.read_csv("Data/PETRARCH output sample 14 18.txt", sep='\t')
petrarch18 = petrarch1418[petrarch1418['root_code']==18].reset_index().drop(['index','Unnamed: 0'], axis = 1)

# %% [markdown]
# ### Parse PETRARCH Root Code 18

# %%
# %time petrarch18['parsed'] = core_parser(petrarch18, 'text')
petrarch18['dep'] = dep_parser(petrarch18, 'text')
# Out:
# CPU times: user 95.1 ms, sys: 22.9 ms, total: 118 ms
# Wall time: 8.22 s

# %%
easy_read(petrarch18, 18)
# Out:
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('NNP', ['May'])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['suicide']), Tree('NN', ['bomber'])]), Tree('VP', [Tree('VBD', ['killed']), Tree('NP', [Tree('NP', [Tree('CD', ['11']), Tree('JJ', ['French']), Tree('NNS', ['engineers'])]), Tree('CC', ['and']), Tree('NP', [Tree('CD', ['two']), Tree('NNPS', ['Pakistanis'])])]), Tree('PP', [Tree('IN', ['near']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['hotel'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Karachi'])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 20 nodes>
# 'Text = In May , a suicide bomber killed 11 French engineers and two Pakistanis near a hotel in Karachi .'
# 'Code = 1831'

# %% [markdown]
# ### Identify instances where ACCENT and PETRARCH found the same event in the same article

# %%
keys = list(["aid", "code"])
petrarch18i1 = petrarch18.set_index(keys).index
assaulti2 = assault.set_index(keys).index
petrarch18_trim = petrarch18[~petrarch18i1.isin(assaulti2)]
both1 = petrarch18[petrarch18i1.isin(assaulti2)]
both_petrarch_coded = both1.sort_values(['aid'])
both_petrarch_coded[['aid', 'code', 'text']]
# Out:
#          aid  code                                               text
# 13  22633569   181  The priest was reported to have been kidnapped...
# 10  22779688   181  Also in early September , armed gunmen seized ...
# 30  22930509   181  The rebels also kidnapped the mayors of the to...
# 18  23850418  1831  In May , a suicide bomber killed 11 French eng...
# 20  23855995   181  The rebels forced the plane to land and kidnap...
# 15  23932147  1831  The move by Mr. Arafat came a day after a Pale...
# 0   23968047   181  In an effort to obtain information about Capta...
# 12  23976893  1831  Two suicide bombers killed at least 56 people ...
# 23  24022493   181  More than 400 foreigners and at least 36 journ...
# 21  24044048  1831  Ten days earlier , a suicide car bomber in the...

# %%
assaulti1 = assault.set_index(keys).index
petrarch18i2 = petrarch18.set_index(keys).index
assault_trim = assault[~assaulti1.isin(petrarch18i2)]
both2 = assault[assaulti1.isin(petrarch18i2)]
both_accent_coded = both2.sort_values(['aid'])
both_accent_coded[['aid', 'code', 'text']]
# Out:
#          aid  code                                               text
# 13  22633569   181  Urban, the Government spokesman, identified th...
# 48  22779688   181  Also in early September, armed gunmen seized a...
# 67  22930509   181  Stepping up their violent effort to stop natio...
# 29  23850418  1831  Five people, including three foreigners, were ...
# 70  23855995   181  The rebels forced the plane to land and kidnap...
# 37  23932147  1831  "Facing renewed threats from Israel, the Pales...
# 21  23968047   181  \n\n\nIn the face of some criticism, Mr. Sharo...
# 32  23976893  1831  "Two suicide bombers killed at least 56 people...
# 22  24022493   181  Al Jazeera said she had asked the kidnappers t...
# 44  24044048  1831  Ten days earlier, a suicide car bomber in the ...

# %%
easy_read(both_accent_coded, 7)
# Out:
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('S', [Tree('NP', [Tree('CD', ['Two']), Tree('NN', ['suicide']), Tree('NNS', ['bombers'])]), Tree('VP', [Tree('VP', [Tree('VBN', ['killed']), Tree('NP', [Tree('QP', [Tree('IN', ['at']), Tree('JJS', ['least']), Tree('CD', ['56'])]), Tree('NNS', ['people'])])]), Tree('CC', ['and']), Tree('VP', [Tree('VBN', ['wounded']), Tree('ADVP', [Tree('NP', [Tree('QP', [Tree('IN', ['at']), Tree('JJS', ['least']), Tree('CD', ['200'])])]), Tree('RB', ['here']), Tree('PP', [Tree('IN', ['on']), Tree('NP-TMP', [Tree('NNP', ['Sunday'])])])]), Tree('PP', [Tree('IN', ['during']), Tree('NP', [Tree('NP', [Tree('JJ', ['Muslim']), Tree('NN', ['holiday']), Tree('NNS', ['celebrations'])]), Tree('PP', [Tree('IN', ['inside']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['separate']), Tree('NN', ['headquarters'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('NNP', ['Iraq']), Tree('POS', ["'s"])]), Tree('CD', ['two'])])])])])])])]), Tree('S', [Tree('VP', [Tree('VBG', ['leading']), Tree('NP', [Tree('JJ', ['Kurdish']), Tree('JJ', ['political']), Tree('NNS', ['parties'])])])])])]), Tree(',', [',']), Tree('NP', [Tree('NNS', ['officials'])]), Tree('VP', [Tree('VBD', ['said'])]), Tree('.', ['.'])])])
# <DependencyGraph with 38 nodes>
# 'Text = "Two suicide bombers killed at least 56 people and wounded at least 200 here on Sunday during Muslim holiday celebrations inside the separate headquarters of Iraq\'s two leading Kurdish political parties, officials said.'
# 'Code = 1831'

# %%
easy_read(both_petrarch_coded, )
# Out:
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('DT', ['an']), Tree('NN', ['effort']), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['obtain']), Tree('NP', [Tree('NN', ['information'])]), Tree('PP', [Tree('IN', ['about']), Tree('NP', [Tree('NNP', ['Captain']), Tree('NNP', ['Arad'])])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('NNP', ['Israeli']), Tree('NNS', ['commandos'])]), Tree('VP', [Tree('VBD', ['kidnapped']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('CD', ['two']), Tree('JJ', ['Lebanese']), Tree('NN', ['guerrilla']), Tree('NNS', ['leaders'])]), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['homes'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('JJ', ['southern']), Tree('NNP', ['Lebanon'])])])])])]), Tree(':', [':']), Tree('NP', [Tree('NP', [Tree('NNP', ['Abdel']), Tree('NNP', ['Karim']), Tree('NNP', ['Obeid'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['cleric'])]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['seized']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1989'])])])])])])])])]), Tree(',', [',']), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('NNP', ['Mustafa']), Tree('NNP', ['Dirani'])]), Tree(',', [',']), Tree('VP', [Tree('VBN', ['captured']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1994'])])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 46 nodes>
# 'Text = In an effort to obtain information about Captain Arad , Israeli commandos kidnapped the two Lebanese guerrilla leaders from their homes in southern Lebanon : Abdel Karim Obeid , a cleric who was seized in 1989 , and Mustafa Dirani , captured in 1994 .'
# 'Code = 181'

# %% [markdown]
# ### Identify instances where ACCENT/PETRARCH found different events in the same article

# %%
new_key = list(['aid'])
petrarch18i10 = petrarch18.set_index(new_key).index
assaulti20 = assault.set_index(new_key).index
petrarch18_trim_2 = petrarch18[~petrarch18i10.isin(assaulti20)]
both10 = petrarch18[petrarch18i10.isin(assaulti20)]
both_petrarch_coded2 = both10.sort_values(['aid'])

# %%
assaulti10 = assault.set_index(new_key).index
petrarch18i20 = petrarch18.set_index(new_key).index
assault_trim_2 = assault[~assaulti10.isin(petrarch18i20)]
both20 = assault[assaulti10.isin(petrarch18i20)]
both_accent_coded2 = both20.sort_values(['aid'])

# %%
i1 = both_petrarch_coded2.set_index(keys).index
i2 = both_accent_coded2.set_index(keys).index
petrarch_trim = both_petrarch_coded2[~i1.isin(i2)]
discard = both_petrarch_coded2[i1.isin(i2)]

# %%
i10 = both_accent_coded2.set_index(keys).index
i20 = both_petrarch_coded2.set_index(keys).index
accent_trim = both_accent_coded2[~i10.isin(i20)]
discard2 = both_accent_coded2[i10.isin(i20)]

# %%
petrarch_slim = petrarch_trim[['aid', 'text', 'parsed', 'dep', 'code']]
accent_slim = accent_trim[['aid', 'text', 'parsed', 'dep', 'code']]
petrarch_slim.sort_values('aid')
# Out:
#          aid                                               text  \
# 32  22709434  The intended holdup victim evidently shot at h...
# 29  22935425  At least nine Palestinians were wounded by arm...
# 26  23547196  The sweep overnight Monday was only the second...
# 5   23809852  Two Palestinian bombers blew themselves up in ...
# 9   23849693  `` It hurts me inside , but I can not say anyt...
# 19  23849693  `` The suicide bombers harm Palestinian intere...
# 7   23850418  In January , the American reporter Daniel Pear...
# 3   23857690  Suicide bombers driving two explosives-laden v...
# 16  23889779  The Israeli offensive did not deter a campaign...
# 4   23971704  Deadly Car-Bombing in Baghdad A suicide car-bo...
# 22  23971884  The car bomb in Baghdad exploded at 7:40 a.m. ...
# 28  23976893  Two suicide bombers killed at least 56 people ...
# 27  24053883  On June 15 , a suicide bomber wearing an army ...
# 2   24054078  A Palestinian suicide bomber set off his explo...
# 17  24068728  But on Sept. 5 , Specialist Williams , a 20-ye...
# 1   24068845  A Palestinian suicide bomber blew himself up W...
# 31  24068845  <umient> <uopts> <ety> 39 </ety> <enum> 0 </en...
#
#                                                parsed  \
# 32  [[[(NP (DT The) (JJ intended) (NN holdup) (NN ...
# 29  [[[(QP (IN At) (JJS least) (CD nine)), (NNPS P...
# 26  [[[(DT The), (NN sweep)], [(JJ overnight), (NN...
# 5   [[[(CD Two), (JJ Palestinian), (NNS bombers)],...
# 9   [[[``], [(S (NP (PRP It)) (VP (VBZ hurts) (NP ...
# 19  [[[``], [(S\n  (NP (DT The) (NN suicide) (NNS ...
# 7   [[[(IN In), (NP (NNP January))], [,], [(DT the...
# 3   [[[(NP (NN Suicide) (NNS bombers)), (VP (VBG d...
# 16  [[[(NP (DT The) (JJ Israeli) (NN offensive)), ...
# 4   [[[(NP (JJ Deadly) (NN Car-Bombing)), (PP (IN ...
# 22  [[[(NP (NP (DT The) (NN car) (NN bomb)) (PP (I...
# 28  [[[(NP (CD Two) (NN suicide) (NNS bombers)), (...
# 27  [[[(IN On), (NP (NNP June) (CD 15))], [,], [(N...
# 2   [[[(NP (DT A) (JJ Palestinian) (NN suicide) (N...
# 17  [[[But], [(IN on), (NP (NNP Sept.) (CD 5))], [...
# 1   [[[(NP (DT A) (JJ Palestinian) (NN suicide) (N...
# 31  [[[(NP\n  (NN <umient>)\n  (NN <uopts>)\n  (NN...
#
#                                                   dep  code
# 32  defaultdict(<function DependencyGraph.__init__...   180
# 29  defaultdict(<function DependencyGraph.__init__...   180
# 26  defaultdict(<function DependencyGraph.__init__...   180
# 5   defaultdict(<function DependencyGraph.__init__...   183
# 9   defaultdict(<function DependencyGraph.__init__...   180
# 19  defaultdict(<function DependencyGraph.__init__...   180
# 7   defaultdict(<function DependencyGraph.__init__...   181
# 3   defaultdict(<function DependencyGraph.__init__...   183
# 16  defaultdict(<function DependencyGraph.__init__...   183
# 4   defaultdict(<function DependencyGraph.__init__...   183
# 22  defaultdict(<function DependencyGraph.__init__...   183
# 28  defaultdict(<function DependencyGraph.__init__...   180
# 27  defaultdict(<function DependencyGraph.__init__...   183
# 2   defaultdict(<function DependencyGraph.__init__...   180
# 17  defaultdict(<function DependencyGraph.__init__...   183
# 1   defaultdict(<function DependencyGraph.__init__...   183
# 31  defaultdict(<function DependencyGraph.__init__...   180

# %%
accent_slim.sort_values('aid')
# Out:
#          aid                                               text  \
# 5   22709434  "A man shot four bystanders when he pulled a g...
# 40  22935425  The army opened fire in Dura, south of Hebron,...
# 89  23547196   the armed wing of Hamas that claimed responsi...
# 30  23809852  Two Palestinian bombers blew themselves up in ...
# 11  23849693  "Ayman Kabaha, an Israeli Arab student killed ...
# 77  23857690  "Suicide bombers driving two explosives-laden ...
# 8   23889779  Dozens of Palestinian gunmen were reported to ...
# 1   23968047  Anwar Yassin, one of the released Lebanese pri...
# 28  23971704  Karbala was founded on the site where Hussein,...
# 83  23971884  On Feb. 1, two suicide bombers walked into sep...
# 66  24053883  On June 15, a suicide bomber wearing an army u...
# 23  24054078   Israeli troops carried out arrest raids in th...
# 9   24068728   U.S. forces begin an assault on Baghdad.\nMay...
# 74  24068845  "A Palestinian suicide bomber blew himself up ...
#
#                                                parsed  \
# 5   [[[``], [(NP\n  (NP (DT A) (NN man))\n  (VP\n ...
# 40  [[[(DT The), (NN army)], [(VBD opened), (NP\n ...
# 89  [[[(NP (DT the) (JJ armed) (NN wing)), (PP\n  ...
# 30  [[[(CD Two), (JJ Palestinian), (NNS bombers)],...
# 11  [[[``], [(NP\n  (NP (NNP Ayman) (NNP Kabaha))\...
# 77  [[[``], [(NP (NN Suicide) (NNS bombers)), (VP ...
# 8   [[[(NP\n  (NP (NNS Dozens))\n  (PP (IN of) (NP...
# 1   [[[(NP\n  (NP (NNP Anwar) (NNP Yassin))\n  (, ...
# 28  [[[(NNP Karbala)], [(VBD was), (VP\n  (VBN fou...
# 83  [[[(IN On), (NP (NNP Feb.) (CD 1) (, ,) (CD tw...
# 66  [[[(IN On), (NP (NNP June) (CD 15))], [(, ,), ...
# 23  [[[(NP\n  (NP (JJ Israeli) (NNS troops))\n  (S...
# 9   [[[(NP (NNP U.S.) (NNS forces)), (VP\n  (VBP b...
# 74  [[[(NP (`` ``) (DT A) (JJ Palestinian) (NN sui...
#
#                                                   dep  code
# 5   defaultdict(<function DependencyGraph.__init__...   181
# 40  defaultdict(<function DependencyGraph.__init__...   181
# 89  defaultdict(<function DependencyGraph.__init__...  1831
# 30  defaultdict(<function DependencyGraph.__init__...  1831
# 11  defaultdict(<function DependencyGraph.__init__...  1831
# 77  defaultdict(<function DependencyGraph.__init__...  1831
# 8   defaultdict(<function DependencyGraph.__init__...  1831
# 1   defaultdict(<function DependencyGraph.__init__...  1831
# 28  defaultdict(<function DependencyGraph.__init__...  1831
# 83  defaultdict(<function DependencyGraph.__init__...  1831
# 66  defaultdict(<function DependencyGraph.__init__...  1831
# 23  defaultdict(<function DependencyGraph.__init__...  1831
# 9   defaultdict(<function DependencyGraph.__init__...  1831
# 74  defaultdict(<function DependencyGraph.__init__...  1831

# %%
def quick_aid_check(corp1, corp2, index1, index2):
    print(corp1['aid'].iloc[index1])
    print(corp2['aid'].iloc[index2])

# %%
quick_aid_check(petrarch_slim, accent_slim, 8, 6)
# Out:
# 23889779
# 23889779

# %%
easy_read(petrarch_slim, 8)
# Out:
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('DT', ['The']), Tree('JJ', ['Israeli']), Tree('NN', ['offensive'])]), Tree('VP', [Tree('VBD', ['did']), Tree('RB', ['not']), Tree('VP', [Tree('VB', ['deter']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['campaign'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['suicide']), Tree('NNS', ['bombings'])])])])])])]), Tree(',', [',']), Tree('CC', ['and']), Tree('S', [Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['seventh']), Tree('NN', ['attack'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['seven']), Tree('NNS', ['days'])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['Palestinian']), Tree('NN', ['bomber'])]), Tree('VP', [Tree('VBD', ['blew']), Tree('NP', [Tree('PRP', ['himself'])]), Tree('PRT', [Tree('RP', ['up'])]), Tree('PP', [Tree('IN', ['near']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['military']), Tree('NN', ['checkpoint'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['border'])]), Tree('PP', [Tree('IN', ['between']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['West']), Tree('NNP', ['Bank'])]), Tree('CC', ['and']), Tree('NP', [Tree('NNP', ['Israel'])])])])])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 42 nodes>
# 'Text = The Israeli offensive did not deter a campaign of suicide bombings , and in the seventh attack in seven days , a Palestinian bomber blew himself up near a military checkpoint on the border between the West Bank and Israel .'
# 'Code = 183'

# %%
easy_read(accent_slim, 6)
# Out:
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NNS', ['Dozens'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['Palestinian']), Tree('NNS', ['gunmen'])])])]), Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VBN', ['reported']), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['have']), Tree('VP', [Tree('VBN', ['moved']), Tree('PP', [Tree('IN', ['into']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Church'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Nativity'])])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['which'])]), Tree('S', [Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['built']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['spot'])]), Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['where'])]), Tree('PRN', [Tree(',', [',']), Tree('S', [Tree('NP', [Tree('NNS', ['Christians'])]), Tree('VP', [Tree('VBP', ['believe'])])]), Tree(',', [','])]), Tree('S', [Tree('NP', [Tree('NNP', ['Jesus'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['born'])])])])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NP', [Tree('NNP', ['nThe']), Tree('NNP', ['Israeli'])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NN', ['offensive'])]), Tree('VP', [Tree('VBD', ['did']), Tree('RB', ['not']), Tree('VP', [Tree('VB', ['deter']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['campaign'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['suicide']), Tree('NNS', ['bombings'])])])])])])])])])])])])])])])])])])])])])])])])]), Tree(',', [',']), Tree('CC', ['and']), Tree('S', [Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['seventh']), Tree('NN', ['attack'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['seven']), Tree('NNS', ['days'])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['Palestinian']), Tree('NN', ['bomber'])]), Tree('VP', [Tree('VBD', ['blew']), Tree('NP', [Tree('PRP', ['himself'])]), Tree('PRT', [Tree('RP', ['up'])]), Tree('PP', [Tree('IN', ['near']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['military']), Tree('NN', ['checkpoint'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['border'])]), Tree('PP', [Tree('IN', ['between']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['West']), Tree('NNP', ['Bank'])]), Tree('CC', ['and']), Tree('NP', [Tree('NNP', ['Israel'])])])])])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 78 nodes>
# 'Text = Dozens of Palestinian gunmen were reported to have moved into the Church of the Nativity, which was built on the spot where, Christians believe, Jesus was born.\\n\\n\\nThe Israeli offensive did not deter a campaign of suicide bombings, and in the seventh attack in seven days, a Palestinian bomber blew himself up near a military checkpoint on the border between the West Bank and Israel.'
# 'Code = 1831'

# %% [markdown]
# ### Look at articles ACCENT coded and PETRARCH didn't

# %%
accent_only_18 = assault_trim_2.reset_index()
easy_read(accent_only_18, 75)
# Out:
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NNS', ['Detainees'])]), Tree('VP', [Tree('VBG', ['holding']), Tree('NP', [Tree('NP', [Tree('CD', ['10']), Tree('NNS', ['hostages'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Talladega']), Tree('NNP', ['Federal']), Tree('NNP', ['Correctional']), Tree('NNP', ['Institution'])])])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Alabama'])])])])]), Tree('VP', [Tree('VBD', ['erected']), Tree('NP', [Tree('NNS', ['signs'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['roof'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['cellblock'])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['they'])]), Tree('VP', [Tree('VBP', ['have']), Tree('VP', [Tree('VBN', ['seized']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NN', ['prison']), Tree('NNS', ['officials'])]), Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VBG', ['denying']), Tree('NP', [Tree('PRP', ['them'])])])])])])])])])])])])])]), Tree('CC', ['and']), Tree('NP', [Tree('DT', ['the']), Tree('NNS', ['hostages']), Tree('NN', ['food'])])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 36 nodes>
# 'Text = Detainees holding 10 hostages at the Talladega Federal Correctional Institution in Alabama erected signs on the roof of the cellblock they have seized that said prison officials were denying them and the hostages food.'
# 'Code = 181'

# %% [markdown]
# ## Look at PETRARCH Null Actor Data

# %%
NYTbd_1418_nullactor = pd.read_csv("Data/NYTbd_1418_nullactor.csv")

# %%
NYTbd_18_nullactor = NYTbd_1418_nullactor[NYTbd_1418_nullactor['code'].isin([181.1831])]

# %%
# %time NYTbd_18_nullactor['parsed'] = core_parser(NYTbd_18_nullactor, 'sentence')
NYTbd_18_nullactor['dep'] = dep_parser(NYTbd_18_nullactor, 'sentence')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# CPU times: user 85.2 ms, sys: 125 ms, total: 210 ms
# Wall time: 2.48 s
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
NYTbd_18_nullactor.reset_index()
len(NYTbd_18_nullactor)
# Out:
# 9

# %% [raw]
# def easy_read_null_actor(corp, index_num):
#     display(corp['parsed'].iloc[index_num])
#     display(corp['dep'].iloc[index_num])
#     display("AID = " + str(corp.iloc[index_num].loc['aid']))
#     display("Source = " + corp.iloc[index_num].loc['source'])
#     display("Target = " + corp.iloc[index_num].loc['target'])
#     display("Sentence = " + corp.iloc[index_num].loc['sentence'])
#     display("Sentence ID = " + str(corp.iloc[index_num].loc['sentence_id']))
#     display("Event Text = " + corp.iloc[index_num].loc['eventtext'])
#     display("Code = " + str(corp.iloc[index_num].loc['code']))

# %%
easy_read_null_actor(NYTbd_18_nullactor, 8)
# Out:
# Tree('ROOT', [Tree('S', [Tree('ADVP', [Tree('RB', ['Back']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NNP', ['Mr.']), Tree('NNP', ['Kehoe']), Tree('POS', ["'s"])]), Tree('NN', ['hometown'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Washington'])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Arkansas']), Tree('JJ', ['grand']), Tree('NN', ['jury'])]), Tree('VP', [Tree('VBD', ['said']), Tree(',', [',']), Tree('S', [Tree('NP', [Tree('NP', [Tree('PRP', ['he'])]), Tree('CC', ['and']), Tree('NP', [Tree('NNP', ['Mr.']), Tree('NNP', ['Lovelace'])])]), Tree('VP', [Tree('VP', [Tree('VBN', ['robbed'])]), Tree('CC', ['and']), Tree('VP', [Tree('VBN', ['kidnapped']), Tree('UCP', [Tree('NP', [Tree('DT', ['a']), Tree('NNP', ['Colville']), Tree('NN', ['couple'])]), Tree(',', [',']), Tree('NP', [Tree('NNP', ['Malcolm']), Tree('CC', ['and']), Tree('NNP', ['Jill']), Tree('NNP', ['Friedman'])]), Tree(',', [',']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NNP', ['June']), Tree('CD', ['12']), Tree(',', [',']), Tree('CD', ['1995'])]), Tree('.', ['.'])])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 39 nodes>
# 'AID = 23625777'
# 'Source = Mr. ... Lovelace.'
# 'Target = a ... Colville couple.'
# "Sentence = Back in Mr. Kehoe 's hometown in Washington , the Arkansas grand jury said , he and Mr. Lovelace robbed and kidnapped a Colville couple , Malcolm and Jill Friedman , on June 12 , 1995 .."
# 'Sentence ID = 34'
# 'Event Text = <and> ... kidnapped.'
# 'Code = 181'

# %% [markdown]
# ## Look at output of PETRARCH after dictionary improvements on 2/11/2020

# %%
PETRARCH_02112020 = pd.read_csv("Data/PETRARCH_14_18_NYTbd_2_11_20.csv")
PETRARCH_02112020_18 = PETRARCH_02112020[PETRARCH_02112020['root_code'] == 18]

# %%
# %time PETRARCH_02112020_18['parsed'] = core_parser(PETRARCH_02112020_18, "text")
PETRARCH_02112020_18['dep'] = dep_parser(PETRARCH_02112020_18, "text")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# CPU times: user 150 ms, sys: 148 ms, total: 297 ms
# Wall time: 7.29 s
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ACCENT_1831 = assault[assault['code'] == 1831]
ACCENT_183 = assault[assault['code'] == 183]
ACCENT_18 = assault[assault['root_code'] == 18]
PETRARCH_02112020_1831 = PETRARCH_02112020_18[PETRARCH_02112020_18['code'] == 1831]
PETRARCH_02112020_183 = PETRARCH_02112020_18[PETRARCH_02112020_18['code'] == 183]
PETRARCH_02112020_181 = PETRARCH_02112020_18[PETRARCH_02112020_18['code'] == 181]

# %%
pd.options.display.max_colwidth = 1000
PETRARCH_02112020_1831[['code', 'text']]
# Out:
#      code  \
# 208  1831
# 273  1831
# 317  1831
# 363  1831
# 368  1831
# 471  1831
# 496  1831
#
#                                                                                                                                                                                                                                 text
# 208      A Palestinian suicide bomber blew himself up Wednesday at a falafel stand in an outdoor market in Hadera , an Israeli coastal town , killing five other people and wounding more than two dozen , the Israeli police said .
# 273                                                                                               On June 15 , a suicide bomber wearing an army uniform blew himself up in an Iraqi Army mess hall in Khalis , killing 26 soldiers .
# 317                                                                                         Ten days earlier , a suicide car bomber in the Shiite city of Hilla killed at least 136 people , mostly Iraqi police and army recruits .
# 363    Two suicide bombers killed at least 56 people and wounded at least 200 here on Sunday during Muslim holiday celebrations inside the separate headquarters of Iraq 's two leading Kurdish political parties , officials said .
# 368                                                                                                                                In May , a suicide bomber killed 11 French engineers and two Pakistanis near a hotel in Karachi .
# 471  The Israeli offensive did not deter a campaign of suicide bombings , and in the seventh attack in seven days , a Palestinian bomber blew himself up near a military checkpoint on the border between the West Bank and Israel .
# 496                                                                                                                       The move by Mr. Arafat came a day after a Palestinian suicide bomber killed 19 people in northern Israel .

# %%
pd.options.display.max_colwidth = 1000
PETRARCH_02112020_181[['code', 'text']]
# Out:
#      code  \
# 253   181
# 345   181
# 415   181
# 552   181
# 568   181
# 589   181
# 617   181
#
#                                                                                                                                                                                                                                                             text
# 253                                                                                                                                                                                              The rebels forced the plane to land and kidnapped a passenger .
# 345                                                                                                                               More than 400 foreigners and at least 36 journalists have been kidnapped in Iraq since 2003 , along with thousands of Iraqis .
# 415                                                                                                  The rebels also kidnapped the mayors of the town of Cojutepeque in Santa Ana dapartment and the town of San Miguel de Mercedes in Chalatenango department .
# 552  In an effort to obtain information about Captain Arad , Israeli commandos kidnapped the two Lebanese guerrilla leaders from their homes in southern Lebanon : Abdel Karim Obeid , a cleric who was seized in 1989 , and Mustafa Dirani , captured in 1994 .
# 568                                                                                                                                                                  In January , the American reporter Daniel Pearl was kidnapped in Karachi and later killed .
# 589                                                                                         The priest was reported to have been kidnapped Oct. 19 by armed men who used their car to block Father Popieluszko 's auto near Torun and then drove away with him .
# 617                                                                                                                  Also in early September , armed gunmen seized a Pan American World Airways flight in Karachi , Pakistan , and took the passengers hostage .

# %%
pd.options.display.max_colwidth = 1000
PETRARCH_02112020_183[['code', 'text']]
# Out:
#      code  \
# 48    183
# 300   183
# 502   183
# 598   183
# 602   183
# 624   183
#
#                                                                                                                                                                                                                                                            text
# 48                                                                                                                                                           Two Palestinian bombers blew themselves up in a pedestrian mall in Jerusalem , killing 11 people .
# 300                                                                                              In Dhaka , anti government rioters ransacked or threw bombs at the homes of one political leader and one member of Parliament from the ruling National Party .
# 502                                                                                                                                             But on Sept. 5 , Specialist Williams , a 20-year old medic , was killed by a roadside bomb in Tal Afar , Iraq .
# 598                                 Deadly Car-Bombing in Baghdad A suicide car-bomb exploded Thursday morning in a line of vehicles at an American checkpoint on a bridge that leads to the compound that houses many of the American administrators in Iraq .
# 602                       The car bomb in Baghdad exploded at 7:40 a.m. on Wednesday outside the recruiting station of the Iraqi Army headquarters , killing at least 25 Iraqis , said Staff sergeant Shane Slaughter , a spokesman for the American military .
# 624  Suicide bombers driving two explosives-laden vehicles blew up the headquarters of Chechnya 's pro-Russian government , killing at least 46 people and wounding more than 75 in one of the deadliest bombings in more than three years of war in Chechnya .

# %% [markdown]
# ## Look at Suicide Bombings that ACCENT found that 02112020 PETRARCH did not find

# %%
ACCENT_1831 # Accent Suicide Bombings
PETRARCH_02112020_1831 # PETRARCH SUICIDE BOMBINGS
keys = list(["aid", "code"])
PETRARCH_02112020_1831i = PETRARCH_02112020_1831.set_index(keys).index
ACCENT_1831i2 = ACCENT_1831.set_index(keys).index
PETRARCH_02112020_1831_trim = PETRARCH_02112020_1831[~PETRARCH_02112020_1831i.isin(ACCENT_1831i2)]
both1 = PETRARCH_02112020_1831[PETRARCH_02112020_1831i.isin(ACCENT_1831i2)]
both_1831_petrarch_coded = both1.sort_values(['aid'])
aid_remove_petrarch = both_1831_petrarch_coded[['aid']]

# %%
ACCENT_1831_MINUS_PETRARCH = ACCENT_1831
cond = ACCENT_1831_MINUS_PETRARCH['aid'].isin(aid_remove_petrarch['aid']) == True
ACCENT_1831_MINUS_PETRARCH.drop(ACCENT_1831_MINUS_PETRARCH[cond].index, inplace = True)
ACCENT_1831_MINUS_PETRARCH.reset_index()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#     index                       document_id       aid  sentence_id  date_str  \
# 0       1  NYTborndigital_20040130_23968047  23968047            1  20040130
# 1       2  NYTborndigital_20050111_24026263  24026263           18  20050111
# 2       3  NYTborndigital_20020708_23851804  23851804           66  20020708
# 3       6  NYTborndigital_20020420_23862466  23862466            6  20020420
# 4       7  NYTborndigital_20020419_23887704  23887704           21  20020419
# 5       9  NYTborndigital_20051026_24068728  24068728          124  20051026
# 6      11  NYTborndigital_20020620_23849693  23849693            0  20020620
# 7      19  NYTborndigital_20050211_24031201  24031201            0  20050211
# 8      23  NYTborndigital_20050713_24054078  24054078           29  20050713
# 9      26  NYTborndigital_20020506_23885794  23885794           12  20020506
# 10     27  NYTborndigital_19960321_23521919  23521919            0  19960321
# 11     28  NYTborndigital_20040506_23971704  23971704           11  20040506
# 12     30  NYTborndigital_20011231_23809852  23809852            1  20011231
# 13     31  NYTborndigital_19941028_23360859  23360859            1  19941028
# 14     33  NYTborndigital_20030619_23943472  23943472            3  20030619
# 15     36  NYTborndigital_20030707_23941399  23941399           25  20030707
# 16     42  NYTborndigital_20051206_24074284  24074284            1  20051206
# 17     43  NYTborndigital_20000610_23736666  23736666           28  20000610
# 18     47  NYTborndigital_19991228_23713872  23713872           10  19991228
# 19     49  NYTborndigital_20021010_23873100  23873100            1  20021010
# 20     50  NYTborndigital_20050301_24033916  24033916           17  20050301
# 21     53  NYTborndigital_20040601_24006322  24006322            8  20040601
# 22     54  NYTborndigital_20050326_24037789  24037789            7  20050326
# 23     55  NYTborndigital_20040129_23972465  23972465            6  20040129
# 24     56  NYTborndigital_20020329_23890419  23890419           20  20020329
# 25     61  NYTborndigital_20030923_23933588  23933588            3  20030923
# 26     63  NYTborndigital_20021201_23861036  23861036            1  20021201
# 27     65  NYTborndigital_20051030_24069309  24069309            0  20051030
# 28     68  NYTborndigital_20051118_24072050  24072050            0  20051118
# 29     69  NYTborndigital_20040516_24007052  24007052           41  20040516
# 30     72  NYTborndigital_19990805_23684648  23684648           36  19990805
# 31     73  NYTborndigital_20050311_24035403  24035403            0  20050311
# 32     77  NYTborndigital_20021229_23857690  23857690            0  20021229
# 33     81  NYTborndigital_20020325_23855331  23855331           25  20020325
# 34     82  NYTborndigital_20040707_24002575  24002575           10  20040707
# 35     83  NYTborndigital_20040211_23971884  23971884           22  20040211
# 36     84  NYTborndigital_20050629_24052281  24052281            6  20050629
# 37     85  NYTborndigital_20000916_23721889  23721889            0  20000916
# 38     86  NYTborndigital_20011230_23810040  23810040           65  20011230
# 39     89  NYTborndigital_19970910_23547196  23547196            3  19970910
# 40     90  NYTborndigital_20041102_23964526  23964526           10  20041102
# 41     95  NYTborndigital_20020703_23882114  23882114            0  20020703
# 42     98  NYTborndigital_20040902_23965618  23965618           28  20040902
#
#           date  year  month  day event_tense  \
# 0   01/30/2004  2004      1   30  historical
# 1   01/11/2005  2005      1   11     neutral
# 2   07/08/2002  2002      7    8     current
# 3   04/20/2002  2002      4   20     neutral
# 4   04/19/2002  2002      4   19     neutral
# 5   10/26/2005  2005     10   26  historical
# 6   06/20/2002  2002      6   20     current
# 7   02/11/2005  2005      2   11  historical
# 8   07/13/2005  2005      7   13     current
# 9   05/06/2002  2002      5    6     neutral
# 10  03/21/1996  1996      3   21     neutral
# 11  05/06/2004  2004      5    6  historical
# 12  12/31/2001  2001     12   31     neutral
# 13  10/28/1994  1994     10   28     neutral
# 14  06/19/2003  2003      6   19     neutral
# 15  07/07/2003  2003      7    7     neutral
# 16  12/06/2005  2005     12    6     neutral
# 17  06/10/2000  2000      6   10     neutral
# 18  12/28/1999  1999     12   28     neutral
# 19  10/10/2002  2002     10   10     current
# 20  03/01/2005  2005      3    1     neutral
# 21  06/01/2004  2004      6    1     current
# 22  03/26/2005  2005      3   26     neutral
# 23  01/29/2004  2004      1   29     neutral
# 24  03/29/2002  2002      3   29     neutral
# 25  09/23/2003  2003      9   23  historical
# 26  12/01/2002  2002     12    1     current
# 27  10/30/2005  2005     10   30     neutral
# 28  11/18/2005  2005     11   18     current
# 29  05/16/2004  2004      5   16     neutral
# 30  08/05/1999  1999      8    5     neutral
# 31  03/11/2005  2005      3   11     neutral
# 32  12/29/2002  2002     12   29     neutral
# 33  03/25/2002  2002      3   25     neutral
# 34  07/07/2004  2004      7    7     neutral
# 35  02/11/2004  2004      2   11     neutral
# 36  06/29/2005  2005      6   29  historical
# 37  09/16/2000  2000      9   16     neutral
# 38  12/30/2001  2001     12   30  historical
# 39  09/10/1997  1997      9   10  historical
# 40  11/02/2004  2004     11    2  historical
# 41  07/03/2002  2002      7    3     neutral
# 42  09/02/2004  2004      9    2     current
#
#                           ...                          source_agent_name  \
# 0                         ...                                 Armed Gang
# 1                         ...                                        NaN
# 2                         ...                                 Armed Gang
# 3                         ...                                 Armed Gang
# 4                         ...                                   Attacker
# 5                         ...                                    Citizen
# 6                         ...                                 Armed Gang
# 7                         ...                                   Attacker
# 8                         ...                                 Armed Gang
# 9                         ...                                        NaN
# 10                        ...                                 Armed Gang
# 11                        ...                                 Armed Gang
# 12                        ...                                    Citizen
# 13                        ...                                        Men
# 14                        ...                                 Armed Gang
# 15                        ...                                   Employee
# 16                        ...                                 Armed Gang
# 17                        ...                                 Armed Gang
# 18                        ...                                 Armed Gang
# 19                        ...                                    Citizen
# 20                        ...                                 Armed Gang
# 21                        ...                                 Armed Gang
# 22                        ...                                 Armed Gang
# 23                        ...                                   Military
# 24                        ...                                 Armed Gang
# 25                        ...                                 Armed Gang
# 26                        ...                                 Armed Gang
# 27                        ...                                 Armed Gang
# 28                        ...                                 Armed Gang
# 29                        ...                                    Citizen
# 30                        ...                                 Armed Gang
# 31                        ...                                 Armed Gang
# 32                        ...                                 Armed Gang
# 33                        ...                                   Militant
# 34                        ...                                 Armed Gang
# 35                        ...                                 Armed Gang
# 36                        ...                                 Armed Gang
# 37                        ...                                 Armed Gang
# 38                        ...                                 Armed Gang
# 39                        ...                                        NaN
# 40                        ...                                 Armed Gang
# 41                        ...                                 Armed Gang
# 42                        ...                                    Citizen
#
#     target_actor_id                target_actor_name target_country_codes  \
# 0           31843.0                           Israel                   IL
# 1           31843.0                           Israel                   IL
# 2           31843.0                           Israel                   IL
# 3           34539.0  Palestinian Territory, Occupied                   PS
# 4           31843.0                           Israel                   IL
# 5           43427.0                   United Nations                  NaN
# 6           31843.0                           Israel                   IL
# 7           31853.0                             Iraq                   IQ
# 8           31843.0                           Israel                   IL
# 9           31843.0                           Israel                   IL
# 10          31843.0                           Israel                   IL
# 11          31853.0                             Iraq                   IQ
# 12          31843.0                           Israel                   IL
# 13          35528.0                           Russia                   RU
# 14          31843.0                           Israel                   IL
# 15          34539.0  Palestinian Territory, Occupied                   PS
# 16          32192.0                       Bangladesh                   BD
# 17          36336.0                        Sri Lanka                   LK
# 18          54063.0                        R. Gandhi                   IN
# 19          31843.0                           Israel                   IL
# 20          31853.0                             Iraq                   IQ
# 21          34185.0                         Pakistan                   PK
# 22          31853.0                             Iraq                   IQ
# 23          31843.0                           Israel                   IL
# 24          31843.0                           Israel                   IL
# 25          31853.0                             Iraq                   IQ
# 26          31843.0                           Israel                   IL
# 27          31853.0                             Iraq                   IQ
# 28          31538.0                           Jordan                   JO
# 29          36716.0                          Morocco                   MA
# 30          36336.0                        Sri Lanka                   LK
# 31          31853.0                             Iraq                   IQ
# 32          35528.0                           Russia                   RU
# 33          31843.0                           Israel                   IL
# 34          31853.0                             Iraq                   IQ
# 35          31853.0                             Iraq                   IQ
# 36          31853.0                             Iraq                   IQ
# 37          36336.0                        Sri Lanka                   LK
# 38          41262.0                    United States                   US
# 39          31843.0                           Israel                   IL
# 40          31843.0                           Israel                   IL
# 41          31843.0                           Israel                   IL
# 42          35528.0                           Russia                   RU
#
#    target_agent_id  target_agent_name  \
# 0            173.0            Citizen
# 1              NaN                NaN
# 2            173.0            Citizen
# 3              NaN                NaN
# 4            173.0            Citizen
# 5              NaN                NaN
# 6            601.0            Student
# 7            173.0            Citizen
# 8              NaN                NaN
# 9              NaN                NaN
# 10           332.0           Military
# 11             NaN                NaN
# 12             NaN                NaN
# 13             NaN                NaN
# 14             NaN                NaN
# 15             NaN                NaN
# 16           173.0            Citizen
# 17           173.0            Citizen
# 18             NaN                NaN
# 19             NaN                NaN
# 20            27.0    Law Enforcement
# 21           173.0            Citizen
# 22           173.0            Citizen
# 23             NaN                NaN
# 24           173.0            Citizen
# 25           173.0            Citizen
# 26             NaN                NaN
# 27           173.0            Citizen
# 28             NaN                NaN
# 29             NaN                NaN
# 30           173.0            Citizen
# 31           173.0            Citizen
# 32           173.0            Citizen
# 33             NaN                NaN
# 34           173.0            Citizen
# 35           173.0            Citizen
# 36           713.0              Women
# 37           173.0            Citizen
# 38           332.0           Military
# 39             NaN                NaN
# 40             NaN                NaN
# 41           173.0            Citizen
# 42             NaN                NaN
#
#                                                  text  batch  \
# 0   Anwar Yassin, one of the released Lebanese pri...     44
# 1   The militant group Hamas, which has carried ou...     59
# 2   \nHe walked down the hall to see a patient who...     69
# 3   It wounded two Israeli soldiers as the bomber ...     34
# 4   The couple were among 28 people killed by a su...     79
# 5    U.S. forces begin an assault on Baghdad.\nMay...     84
# 6   "Ayman Kabaha, an Israeli Arab student killed ...     84
# 7   "A black-robed suicide attacker exploded an en...     74
# 8    Israeli troops carried out arrest raids in th...     44
# 9   \n\n\nA Western diplomat said the Israeli offi...     79
# 10  "The Israeli Army said that a suicide bomber f...     23
# 11  Karbala was founded on the site where Hussein,...     54
# 12  Two Palestinian bombers blew themselves up in ...     59
# 13  Security officials said the man tried to comma...     17
# 14   a suicide bomber blew himself up at a grocery...     74
# 15   though Palestinians shot and killed a Bulgari...     14
# 16  The victims included Anwarul Azim, the assista...     44
# 17  t;break/&gt;\n\n\n\nSRI LANKA: 60 HELD IN BLAS...     18
# 18  He was killed at an election rally in Tamil Na...     13
# 19  [A Palestinian wounded five people, one seriou...     69
# 20  In southern Baghdad, a suicide bomber drove in...     84
# 21  Violence between Sunnis and Shiites has killed...     69
# 22  The general's two sons were wounded in the att...     79
# 23  The Palestinians also fired rocket-propelled g...     89
# 24  On Wednesday, speaking before a Palestinian su...     34
# 25  In all, one Iraqi investigator said, the man w...     34
# 26  And that, most likely, is exactly what the ter...     39
# 27  "A suicide bomber drove a pickup truck loaded ...     29
# 28  "The mother of the bride whose wedding was und...     29
# 29  The Spanish authorities said they were able to...     44
# 30  Seth Mydans (NYT)\n\n\n\nSRI LANKA: BOMBER STR...     43
# 31  "A suicide bomber walked into a Shiite mosque ...     74
# 32  "Suicide bombers driving two explosives-laden ...     64
# 33  But since then Palestinian militants have carr...     79
# 34  \n\nBOMBING'S TOLL -- At least five people wer...     34
# 35  On Feb. 1, two suicide bombers walked into sep...     24
# 36  Even in elementary school, she told relatives ...     24
# 37  "The suicide bomber's head, with its neatly ba...     14
# 38  Mr. bin Laden was on the run, deprived of the ...     14
# 39   the armed wing of Hamas that claimed responsi...     83
# 40  \n\n\nThe last suicide bomber, who blew hersel...     59
# 41  "Had 19-year old Ariella Marcus not told her f...      8
# 42  Law enforcement officials on Wednesday circula...     49
#
#                                                parsed  \
# 0   [[[(NP\n  (NP (NNP Anwar) (NNP Yassin))\n  (, ...
# 1   [[[(NP (DT The) (JJ militant) (NN group) (NNP ...
# 2   [[[(X (SYM \)), (NP (NN nHe))], [(VBD walked),...
# 3   [[[(PRP It)], [(VBD wounded), (NP (CD two) (JJ...
# 4   [[[(NP (DT The) (NN couple)), (VP\n  (VBD were...
# 5   [[[(NP (NNP U.S.) (NNS forces)), (VP\n  (VBP b...
# 6   [[[``], [(NP\n  (NP (NNP Ayman) (NNP Kabaha))\...
# 7   [[[(`` ``), (DT A), (JJ black-robed), (NN suic...
# 8   [[[(NP\n  (NP (JJ Israeli) (NNS troops))\n  (S...
# 9   [[[(SYM \)], [(NP (NN n) (NN \) (NN n)), (SBAR...
# 10  [[[``], [(DT The), (JJ Israeli), (NNP Army)], ...
# 11  [[[(NNP Karbala)], [(VBD was), (VP\n  (VBN fou...
# 12  [[[(CD Two), (JJ Palestinian), (NNS bombers)],...
# 13  [[[(NP (NN Security) (NNS officials)), (VP\n  ...
# 14  [[[(NP (DT a) (NN suicide) (NN bomber)), (VP\n...
# 15  [[[(IN though), (NP\n  (NP\n    (NP (NNPS Pale...
# 16  [[[(DT The), (NNS victims)], [(VBD included), ...
# 17  [[[(NP (NN t)), (: ;), (NP (NN break))], [/], ...
# 18  [[[(PRP He)], [(VBD was), (VP\n  (VBN killed)\...
# 19  [[[(-LRB- -LSB-), (S\n  (NP (DT A) (NN Palesti...
# 20  [[[(IN In), (NP (JJ southern) (NNP Baghdad))],...
# 21  [[[(NP (NN Violence)), (PP\n  (IN between)\n  ...
# 22  [[[(NP (NP (DT The) (NN general) (POS 's)) (CD...
# 23  [[[(NP (DT The) (NNPS Palestinians)), (ADVP (R...
# 24  [[[(IN On), (NP (NNP Wednesday))], [,], [(VP\n...
# 25  [[[(IN In), (NP (DT all))], [,], [(CD one), (J...
# 26  [[[And], [(NP (DT that)), (SBAR\n  (S\n    (, ...
# 27  [[[(NP (`` ``) (DT A) (NN suicide)), (SBAR\n  ...
# 28  [[[``], [(NP (DT The) (NN mother)), (PP\n  (IN...
# 29  [[[(DT The), (JJ Spanish), (NNS authorities)],...
# 30  [[[(NP (NNP Seth) (NNP Mydans)), (PRN (-LRB- -...
# 31  [[[``], [(NP (DT A) (NN suicide) (NN bomber)),...
# 32  [[[``], [(NP (NN Suicide) (NNS bombers)), (VP ...
# 33  [[[But], [(IN since), (NP (RB then))], [(NP (J...
# 34  [[[(NP (NN \) (NN n)), (VP (VBG \) (NP (NP (NN...
# 35  [[[(IN On), (NP (NNP Feb.) (CD 1) (, ,) (CD tw...
# 36  [[[(RB Even), (S\n  (PP (IN in) (NP (JJ elemen...
# 37  [[[``], [(NP\n  (NP (NP (DT The) (NN suicide) ...
# 38  [[[(NP (NNP Mr.) (NNP bin) (NNP Laden)), (VP\n...
# 39  [[[(NP (DT the) (JJ armed) (NN wing)), (PP\n  ...
# 40  [[[(X (SYM \)), (S\n  (NP\n    (NP (NN n) (NN ...
# 41  [[[``], [(S\n  (VP\n    (VBD Had)\n    (NP\n  ...
# 42  [[[(NP (NN Law) (NN enforcement) (NNS official...
#
#                                                   dep
# 0   defaultdict(<function DependencyGraph.__init__...
# 1   defaultdict(<function DependencyGraph.__init__...
# 2   defaultdict(<function DependencyGraph.__init__...
# 3   defaultdict(<function DependencyGraph.__init__...
# 4   defaultdict(<function DependencyGraph.__init__...
# 5   defaultdict(<function DependencyGraph.__init__...
# 6   defaultdict(<function DependencyGraph.__init__...
# 7   defaultdict(<function DependencyGraph.__init__...
# 8   defaultdict(<function DependencyGraph.__init__...
# 9   defaultdict(<function DependencyGraph.__init__...
# 10  defaultdict(<function DependencyGraph.__init__...
# 11  defaultdict(<function DependencyGraph.__init__...
# 12  defaultdict(<function DependencyGraph.__init__...
# 13  defaultdict(<function DependencyGraph.__init__...
# 14  defaultdict(<function DependencyGraph.__init__...
# 15  defaultdict(<function DependencyGraph.__init__...
# 16  defaultdict(<function DependencyGraph.__init__...
# 17  defaultdict(<function DependencyGraph.__init__...
# 18  defaultdict(<function DependencyGraph.__init__...
# 19  defaultdict(<function DependencyGraph.__init__...
# 20  defaultdict(<function DependencyGraph.__init__...
# 21  defaultdict(<function DependencyGraph.__init__...
# 22  defaultdict(<function DependencyGraph.__init__...
# 23  defaultdict(<function DependencyGraph.__init__...
# 24  defaultdict(<function DependencyGraph.__init__...
# 25  defaultdict(<function DependencyGraph.__init__...
# 26  defaultdict(<function DependencyGraph.__init__...
# 27  defaultdict(<function DependencyGraph.__init__...
# 28  defaultdict(<function DependencyGraph.__init__...
# 29  defaultdict(<function DependencyGraph.__init__...
# 30  defaultdict(<function DependencyGraph.__init__...
# 31  defaultdict(<function DependencyGraph.__init__...
# 32  defaultdict(<function DependencyGraph.__init__...
# 33  defaultdict(<function DependencyGraph.__init__...
# 34  defaultdict(<function DependencyGraph.__init__...
# 35  defaultdict(<function DependencyGraph.__init__...
# 36  defaultdict(<function DependencyGraph.__init__...
# 37  defaultdict(<function DependencyGraph.__init__...
# 38  defaultdict(<function DependencyGraph.__init__...
# 39  defaultdict(<function DependencyGraph.__init__...
# 40  defaultdict(<function DependencyGraph.__init__...
# 41  defaultdict(<function DependencyGraph.__init__...
# 42  defaultdict(<function DependencyGraph.__init__...
#
# [43 rows x 26 columns]

# %%
easy_read(both_1831_petrarch_coded, 6)
# Out:
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('DT', ['A']), Tree('JJ', ['Palestinian']), Tree('NN', ['suicide']), Tree('NN', ['bomber'])]), Tree('VP', [Tree('VBD', ['blew']), Tree('NP', [Tree('PRP', ['himself'])]), Tree('ADVP', [Tree('RP', ['up'])]), Tree('NP-TMP', [Tree('NNP', ['Wednesday'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['falafel']), Tree('S', [Tree('VP', [Tree('VB', ['stand']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['outdoor']), Tree('NN', ['market'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Hadera'])])])])])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['Israeli']), Tree('JJ', ['coastal']), Tree('NN', ['town'])]), Tree(',', [',']), Tree('S', [Tree('VP', [Tree('VP', [Tree('VBG', ['killing']), Tree('NP', [Tree('CD', ['five']), Tree('JJ', ['other']), Tree('NNS', ['people'])])]), Tree('CC', ['and']), Tree('VP', [Tree('VBG', ['wounding']), Tree('NP', [Tree('QP', [Tree('JJR', ['more']), Tree('IN', ['than']), Tree('CD', ['two']), Tree('NN', ['dozen'])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['Israeli']), Tree('NN', ['police'])]), Tree('VP', [Tree('VBD', ['said'])]), Tree('.', ['.'])])])
# <DependencyGraph with 41 nodes>
# 'Text = A Palestinian suicide bomber blew himself up Wednesday at a falafel stand in an outdoor market in Hadera , an Israeli coastal town , killing five other people and wounding more than two dozen , the Israeli police said .'
# 'Code = 1831'

# %%
easy_read(ACCENT_1831, 4)
# Out:
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('DT', ['The']), Tree('NN', ['couple'])]), Tree('VP', [Tree('VBD', ['were']), Tree('PP', [Tree('IN', ['among']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('CD', ['28']), Tree('NNS', ['people'])]), Tree('VP', [Tree('VBN', ['killed']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['suicide']), Tree('NN', ['attacker'])])]), Tree('S', [Tree('VP', [Tree('VBG', ['carrying']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['large']), Tree(',', [',']), Tree('JJ', ['weapons-grade']), Tree('NN', ['bomb'])])])])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n']), Tree('NN', ['\\']), Tree('NN', ['n'])])])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NNP', ['nFor']), Tree('NNP', ['Mr.']), Tree('NNP', ['Bartov'])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['emotional']), Tree('NN', ['wound'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('ADVP', [Tree('RB', ['still'])]), Tree('ADJP', [Tree('JJ', ['fresh'])])]), Tree('.', ['.'])])])
# <DependencyGraph with 37 nodes>
# 'Text = The couple were among 28 people killed by a suicide attacker carrying a large, weapons-grade bomb.\\n\\n\\n\\nFor Mr. Bartov, the emotional wound is still fresh.'
# 'Code = 1831'

# %% [markdown]
# ## Look at articles where ACCENT coded 1831 and  02112020 PETRARCH found different events

# %%
new_key = list(['aid'])
PETRARCH_02112020_18i = PETRARCH_02112020_18.set_index(new_key).index
ACCENT_1831i = ACCENT_1831.set_index(new_key).index
PETRARCH_02112020_TRIM = PETRARCH_02112020_18[~PETRARCH_02112020_18i.isin(ACCENT_1831i)]
SAME_AID_PETRARCH_02112020_18 = PETRARCH_02112020_18[PETRARCH_02112020_18i.isin(ACCENT_1831i)]
SAME_AID_PETRARCH_02112020_18 = SAME_AID_PETRARCH_02112020_18.sort_values('aid').reset_index()
len(SAME_AID_PETRARCH_02112020_18)
# Out:
# 9

# %%
ACCENT_TRIM = ACCENT_1831[~ACCENT_1831i.isin(PETRARCH_02112020_18i)]
BOTH_ACCENT_1831 = ACCENT_1831[ACCENT_1831i.isin(PETRARCH_02112020_18i)]
SAME_AID_ACCENT_1831_CODED = BOTH_ACCENT_1831.sort_values(['aid'])
SAME_AID_ACCENT_1831_CODED = SAME_AID_ACCENT_1831_CODED.sort_values('aid').reset_index()
len(SAME_AID_ACCENT_1831_CODED)
# Out:
# 8

# %%
quick_aid_check(SAME_AID_PETRARCH_02112020_18, SAME_AID_ACCENT_1831_CODED, 5, 7)
# Out:
# 23968047
# 24068728

# %%
easy_read(SAME_AID_PETRARCH_02112020_18, 5)
# Out:
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('DT', ['an']), Tree('NN', ['effort']), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['obtain']), Tree('NP', [Tree('NN', ['information'])]), Tree('PP', [Tree('IN', ['about']), Tree('NP', [Tree('NNP', ['Captain']), Tree('NNP', ['Arad'])])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('NNP', ['Israeli']), Tree('NNS', ['commandos'])]), Tree('VP', [Tree('VBD', ['kidnapped']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('CD', ['two']), Tree('JJ', ['Lebanese']), Tree('NN', ['guerrilla']), Tree('NNS', ['leaders'])]), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['homes'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('JJ', ['southern']), Tree('NNP', ['Lebanon'])])])])])]), Tree(':', [':']), Tree('NP', [Tree('NP', [Tree('NNP', ['Abdel']), Tree('NNP', ['Karim']), Tree('NNP', ['Obeid'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['cleric'])]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['seized']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1989'])])])])])])])])]), Tree(',', [',']), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('NNP', ['Mustafa']), Tree('NNP', ['Dirani'])]), Tree(',', [',']), Tree('VP', [Tree('VBN', ['captured']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1994'])])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 46 nodes>
# 'Text = In an effort to obtain information about Captain Arad , Israeli commandos kidnapped the two Lebanese guerrilla leaders from their homes in southern Lebanon : Abdel Karim Obeid , a cleric who was seized in 1989 , and Mustafa Dirani , captured in 1994 .'
# 'Code = 181'

# %%
easy_read(SAME_AID_ACCENT_1831_CODED, 4)
# Out:
# Tree('ROOT', [Tree('SINV', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NNP', ['Anwar']), Tree('NNP', ['Yassin'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('CD', ['one'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('ADJP', [Tree('VBN', ['released'])]), Tree('JJ', ['Lebanese']), Tree('NNS', ['prisoners'])])])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['held']), Tree('PP', [Tree('IN', ['since']), Tree('NP', [Tree('CD', ['1987'])])])])]), Tree(',', [',']), Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('IN', ['as']), Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['flashed']), Tree('NP', [Tree('NN', ['victory']), Tree('NNS', ['signs'])]), Tree('PP', [Tree('IN', ['after']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['day'])]), Tree('SBAR', [Tree('WHPP', [Tree('IN', ['in']), Tree('WHNP', [Tree('WDT', ['which'])])]), Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['traveled']), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('PRP$', ['his']), Tree('NN', ['jail']), Tree('NN', ['cell'])])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Israel'])])]), Tree('PP', [Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NP', [Tree('NNP', ['Cologne']), Tree(',', [',']), Tree('NNP', ['Germany'])]), Tree(',', [',']), Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['where'])]), Tree('S', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['exchange'])]), Tree('VP', [Tree('VBD', ['took']), Tree('NP', [Tree('NN', ['place'])])])])])])]), Tree(',', [',']), Tree('CC', ['and']), Tree('ADVP', [Tree('RB', ['then'])]), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NP', [Tree('NN', ['freedom'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('NNP', ['Beirut']), Tree('.', ['.'])]), Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])])])])])])])])])])])])])])])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n']), Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('S', [Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NP', [Tree('NNP', ['nIn']), Tree('NNP', ['Israel'])]), Tree('PRN', [Tree(',', [',']), Tree('S', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['mood'])]), Tree('VP', [Tree('VBD', ['was']), Tree('ADJP', [Tree('JJ', ['somber'])])])]), Tree(',', [','])])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('JJ', ['much']), Tree('JJ', ['mixed']), Tree('NN', ['emotion'])])]), Tree('PP', [Tree('IN', ['at']), Tree('S', [Tree('VP', [Tree('VBG', ['dealing']), Tree('PP', [Tree('PP', [Tree('IN', ['with']), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['what'])]), Tree('S', [Tree('NP', [Tree('PRP', ['it'])]), Tree('VP', [Tree('VBZ', ['considers']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['terrorist']), Tree('NN', ['group'])])])])])]), Tree('CC', ['and']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['day'])]), Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['when'])]), Tree('S', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['Palestinian']), Tree('NN', ['suicide']), Tree('NN', ['bomber'])]), Tree('VP', [Tree('VBD', ['killed']), Tree('NP', [Tree('CD', ['10']), Tree('NNPS', ['Israelis'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Jerusalem'])])])])])])])])])])])])])]), Tree('.', ['.'])])])
# <DependencyGraph with 95 nodes>
# 'Text = Anwar Yassin, one of the released Lebanese prisoners, held since 1987, said as he flashed victory signs after a day in which he traveled from his jail cell in Israel to Cologne, Germany, where the exchange took place, and then to freedom in Beirut.\\n\\n\\n\\nIn Israel, the mood was somber, with much mixed emotion at dealing with what it considers a terrorist group and on a day when a Palestinian suicide bomber killed 10 Israelis in Jerusalem.'
# 'Code = 1831'

# %% [markdown]
# ### Looking inside ACCENT Coded 1831 Events at the Sentence Level

# %%
# loop runs ACCENT 1831 events through STANFORD_NLP Python Package 
SAME_AID_ACCENT_1831_CODED['doc'] = ""
for i in range(len(SAME_AID_ACCENT_1831_CODED)):
    SAME_AID_ACCENT_1831_CODED['doc'].iloc[i] = nlp(SAME_AID_ACCENT_1831_CODED['text'].iloc[i])
# Out:
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
SAME_AID_ACCENT_1831_CODED['aid'].iloc[4]
# Out:
# 23968047

# %%
SAME_AID_ACCENT_1831_CODED['text'].iloc[4]
# Out:
# 'Anwar Yassin, one of the released Lebanese prisoners, held since 1987, said as he flashed victory signs after a day in which he traveled from his jail cell in Israel to Cologne, Germany, where the exchange took place, and then to freedom in Beirut.\\n\\n\\n\\nIn Israel, the mood was somber, with much mixed emotion at dealing with what it considers a terrorist group and on a day when a Palestinian suicide bomber killed 10 Israelis in Jerusalem.'

# %%
SAME_AID_ACCENT_1831_CODED['doc'].iloc[4].sentences[1].print_dependencies()
# Out:
# ('In', '2', 'case')
# ('Israel', '7', 'obl')
# (',', '7', 'punct')
# ('the', '5', 'det')
# ('mood', '7', 'nsubj')
# ('was', '7', 'cop')
# ('somber', '0', 'root')
# (',', '7', 'punct')
# ('with', '12', 'case')
# ('much', '11', 'advmod')
# ('mixed', '12', 'amod')
# ('emotion', '7', 'obl')
# ('at', '14', 'mark')
# ('dealing', '12', 'acl')
# ('with', '16', 'case')
# ('what', '14', 'obl')
# ('it', '18', 'nsubj')
# ('considers', '16', 'acl:relcl')
# ('a', '21', 'det')
# ('terrorist', '21', 'amod')
# ('group', '18', 'obj')
# ('and', '25', 'cc')
# ('on', '25', 'case')
# ('a', '25', 'det')
# ('day', '21', 'conj')
# ('when', '31', 'mark')
# ('a', '30', 'det')
# ('Palestinian', '30', 'amod')
# ('suicide', '30', 'compound')
# ('bomber', '31', 'nsubj')
# ('killed', '25', 'advcl')
# ('10', '33', 'nummod')
# ('Israelis', '31', 'obj')
# ('in', '35', 'case')
# ('Jerusalem', '31', 'obl')
# ('.', '7', 'punct')

# %% [markdown]
# ### Looking at PETRARCH 1831 Events at the Sentence Level

# %%
# loop runs PETRARCH 1831 events through STANFORD_NLP Python Package 
PETRARCH_02112020_1831['doc'] = ""
for i in range(len(PETRARCH_02112020_1831)):
    PETRARCH_02112020_1831['doc'].iloc[i] = nlp(PETRARCH_02112020_1831['text'].iloc[i])
# loop runs PETRARCH 18 articles that ACCENT coded 1831 through STANFORD_NLP Python Package 
SAME_AID_PETRARCH_02112020_18['doc'] = ""
for i in range(len(SAME_AID_PETRARCH_02112020_18)):
    SAME_AID_PETRARCH_02112020_18['doc'].iloc[i] = nlp(SAME_AID_PETRARCH_02112020_18['text'].iloc[i])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
SAME_AID_PETRARCH_02112020_18['aid'].iloc[0]
# Out:
# 23547196

# %%
SAME_AID_PETRARCH_02112020_18['text'].iloc[0]
# Out:
# 'The sweep overnight Monday was only the second large roundup since the Palestinian Authority took power in the Gaza Strip and parts of the West Bank .'

# %%
SAME_AID_PETRARCH_02112020_18['doc'].iloc[0].sentences[0].print_dependencies()
# Out:
# ('The', '3', 'det')
# ('sweep', '3', 'compound')
# ('overnight', '10', 'nsubj')
# ('Monday', '10', 'nsubj')
# ('was', '10', 'cop')
# ('only', '10', 'advmod')
# ('the', '10', 'det')
# ('second', '10', 'amod')
# ('large', '10', 'amod')
# ('roundup', '0', 'root')
# ('since', '15', 'mark')
# ('the', '14', 'det')
# ('Palestinian', '14', 'compound')
# ('Authority', '15', 'nsubj')
# ('took', '10', 'advcl')
# ('power', '15', 'obj')
# ('in', '20', 'case')
# ('the', '20', 'det')
# ('Gaza', '20', 'compound')
# ('Strip', '15', 'obl')
# ('and', '22', 'cc')
# ('parts', '20', 'conj')
# ('of', '26', 'case')
# ('the', '26', 'det')
# ('West', '26', 'compound')
# ('Bank', '22', 'nmod')
# ('.', '10', 'punct')

# %% [markdown]
# # Extraneous Projects
# #### py-CoreNLP Wrapper

# %%
from pycorenlp import StanfordCoreNLP

nlp = StanfordCoreNLP('http://localhost:9000')

def depparse(text):
    parsed=""
    output = nlp.annotate(text, properties={
      'annotators': 'depparse',
      'outputFormat': 'json'
      })

    for i in output["sentences"]:
        for j in i["basicDependencies"]:
            parsed=parsed+str(j["dep"]+'('+ j["governorGloss"]+' ')+str(j["dependentGloss"]+')'+' ')
        return parsed
text="I put the book in the box on the table."

# %% [markdown]
# #### Stanford NLP Python Package Parser
# The sentence structure of the BBN/ACCENT output makes it impossible to loop through... going to need to do some REGEX work on it to get it into a format where sentences are not broken up. Assuming 'nlp' command breaks up sentences at any '.' which is going to be a problem when trying to clean it up.

# %%
import stanfordnlp
stanfordnlp.download('en')   # This downloads the English models for the neural pipeline
nlp = stanfordnlp.Pipeline() # This sets up a default neural pipeline in English

# %%
doc = nlp("A suicide truck bomber destroys the U.N. headquarters in Baghdad.")
doc.sentences[0].print_dependencies()
# Out:
# ('A', '4', 'det')
# ('suicide', '3', 'compound')
# ('truck', '4', 'compound')
# ('bomber', '5', 'nsubj')
# ('destroys', '0', 'root')
# ('the', '8', 'det')
# ('U.N.', '8', 'compound')
# ('headquarters', '5', 'obj')
# ('in', '10', 'case')
# ('Baghdad', '5', 'obl')
# ('.', '5', 'punct')
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
def stanlp(df, col):
    for i in range(len(df)):
        arg = nlp(df[col].iloc[i])
    return arg

# %%
flop = stanlp(protest_violent, "text")
# Out:
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# ../aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
flop.sentences[2].print_dependencies()
# Out:
# ('The', '2', 'det')
# ('crowd', '14', 'nsubj')
# ('in', '4', 'case')
# ('Sidon', '2', 'nmod')
# ('today', '2', 'nmod:tmod')
# (',', '2', 'punct')
# ('led', '2', 'acl')
# ('by', '10', 'case')
# ('the', '10', 'det')
# ('Party', '7', 'obl')
# ('of', '12', 'case')
# ('God', '10', 'nmod')
# (',', '14', 'punct')
# ('staged', '0', 'root')
# ('a', '16', 'det')
# ('rally', '14', 'obj')
# ('in', '18', 'case')
# ('front', '14', 'obl')
# ('of', '22', 'case')
# ('the', '22', 'det')
# ('main', '22', 'amod')
# ('mosque', '18', 'nmod')
# ('and', '24', 'cc')
# ('rounded', '14', 'conj')
# ('out', '24', 'compound:prt')
# ('the', '27', 'det')
# ('day', '24', 'obl:tmod')
# ('by', '29', 'mark')
# ('burning', '24', 'advcl')
# ('three', '31', 'nummod')
# ('bars', '29', 'obj')
# ('and', '33', 'cc')
# ('smashing', '29', 'conj')
# ('whisky', '35', 'compound')
# ('bottles', '33', 'obj')
# ('in', '38', 'case')
# ('several', '38', 'amod')
# ('stores', '33', 'obl')
# (',', '33', 'punct')
# ('according', '42', 'case')
# ('to', '40', 'fixed')
# ('reports', '29', 'obl')
# ('reaching', '42', 'acl')
# ('the', '45', 'det')
# ('capitol', '43', 'obj')
# ('.', '14', 'punct')
