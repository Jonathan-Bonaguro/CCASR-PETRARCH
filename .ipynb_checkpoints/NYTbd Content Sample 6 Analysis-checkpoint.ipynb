# %% [markdown]
# # Analyzing NYTbd Sample 6
# <br>
# This notebook is looking at the NYTbd Sample 6 content analyzed by ACCENT and PETRARCH2 to identify current limitations with PETRARCH2 and to try and devise solutions.

# %%
# Setup Environment
import nltk

from nltk.parse.corenlp import CoreNLPServer
from nltk.parse.corenlp import CoreNLPDependencyParser
from nltk.parse import CoreNLPParser

import pandas as pd

import pprint

from nltk.tree import *
from IPython.display import display

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# #### Link to Java Server for Standford CoreNLP
# <br>
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -annotators "tokenize,ssplit,pos,lemma,parse,sentiment" -port 9000 -timeout 100000

# %%
# Connect to Server
parser = CoreNLPParser('http://localhost:9000')
depr = CoreNLPDependencyParser('http://localhost:9000')

# %% [markdown]
# #### Write Some Functions for Parsing Text

# %%
# Core Parser- save as df['parsed']
def core_parser(df, col):
    parse = []
    i = ""
    for i in range(len(df)):
        parse.append(i)
        parse[i] = next(parser.raw_parse(df[col].iloc[i]))
    return parse

# Dependency Parser- save as df['dep']
def dep_parser(df, col):
    dep = []
    i = ""
    for i in range(len(df)):
        dep.append(i)
        dep[i] = next(depr.raw_parse(df[col].iloc[i]))
    return dep

# For easy display of both parse trees, text, and code
def easy_read(corp, index_num):
    display(corp['parsed'].iloc[index_num])
    display(corp['dep'].iloc[index_num])
    display("Text = " + corp.iloc[index_num].loc['text'])
    display("Code = " + str(corp.iloc[index_num].loc['code']))
    
# function to display only constituency parse with POS tags with text and code
def parsed_output(corp, index_num):
    display("AID = " + str(corp.iloc[index_num].loc['aid']))
    display("Code = " + str(corp.iloc[index_num].loc['code']))
    display("Text = " + corp.iloc[index_num].loc['text'])
    display(corp['parsed'].iloc[index_num])

# function to display only dependency parse with text and code
def dependency_output(corp, index_num):
    display(corp['dep'].iloc[index_num])
    display("Text = " + corp.iloc[index_num].loc['text'])
    display("Code = " + str(corp.iloc[index_num].loc['code']))
    
# function to display constituency parse of a single sentence
def one_sentence_parser(text):
    output = next(parser.raw_parse(text))
    return output

# %% [markdown]
# ## Read in NYTbd Sample 6 Data- ACCENT and PETRARCH

# %%
accent6 = pd.read_stata("/Volumes/PartTime/Jonathan Bonaguro - Spring 2020/NYTbd sample 6/Run1/Accent_sample6_events_text.dta")
petrarch6_full = pd.read_stata("/Volumes/PartTime/Jonathan Bonaguro - Spring 2020/NYTbd sample 6/Run1/NYTbd_sample6_run1_events_text.dta")

# %%
# Convert Data Types to int32
petrarch6_full['code'] = petrarch6_full['code'].astype('int32')
petrarch6_full['aid'] = petrarch6_full['aid'].astype('int32')

accent6['code'] = accent6['code'].astype('int32')
accent6['aid'] = accent6['aid'].astype('int32')

# extract relevant_codes from accent6
relevant_codes = accent6.code.unique()

# trim petrarch6_full down to relevant codes
petrarch6 = petrarch6_full[petrarch6_full['code'].isin(relevant_codes)]

# %% [markdown]
# ## Parse Text

# %%
# %time 
accent6['parsed'] = core_parser(accent6, 'text')
accent6['dep'] = dep_parser(accent6, 'text')

petrarch6['parsed'] = core_parser(petrarch6, 'text')
petrarch6['dep'] = dep_parser(petrarch6, 'text')
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# /Users/jonathanbonaguro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/jonathanbonaguro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
keys = list(['aid', 'code'])
accent6_index = accent6.set_index(keys).index
petrarch6_index = petrarch6.set_index(keys).index

# Produce df's of mutually exclusive events 
accent6_only = accent6[~accent6_index.isin(petrarch6_index)]
petrarch6_only = petrarch6[~petrarch6_index.isin(accent6_index)]

# Produce df's of same article, same coding
accent6_same_code = accent6[accent6_index.isin(petrarch6_index)]
petrarch6_same_code = petrarch6[petrarch6_index.isin(accent6_index)]

# sort values on AID and reset index 
accent6_only = accent6_only.sort_values('aid').reset_index(drop = True)
petrarch6_only = petrarch6_only.sort_values('aid').reset_index(drop = True)

accent6_same_code = accent6_same_code.sort_values('aid').reset_index(drop = True)
petrarch6_same_code = petrarch6_same_code.sort_values('aid').reset_index(drop = True)

# %% [markdown]
# ## Look for errors in ACCENT and remove from data
# <br>
# Event codes: 1711, 1712, 1724, 182, 1821, 1822, 1823, 185, 186

# %%
# for i in range(len(accent6_only[accent6_only.code == 182])):
#     parsed_output(accent6_only[accent6_only.code == 182], i)
#     display(i)

# %%
# trim errors out of ACCENT output : refer to "ACCENT_SAMPLE5_ERRORS.docx" for documentation of errors
accent6_1711 = accent6_only[accent6_only.code == 1711].reset_index(drop = True).drop([1, 2, 3, 4, 11, 12, 23]).reset_index(drop = True)

accent6_1712 = accent6_only[accent6_only.code == 1712].reset_index(drop = True).drop([0, 2, 7, 8, 9, 15, 18]).reset_index(drop = True)

accent6_1724 = accent6_only[accent6_only.code == 1724].reset_index(drop = True)

accent6_182 = accent6_only[accent6_only.code == 182].reset_index(drop = True).drop([3, 4, 8, 9, 10, 11, 12, 13, 14, 15, 18, 22, 23, 24]).reset_index(drop = True)

accent6_1821 = accent6_only[accent6_only.code == 1821].reset_index(drop = True)

accent6_1822 = accent6_only[accent6_only.code == 1822].reset_index(drop = True)

accent6_1823 = accent6_only[accent6_only.code == 1823].reset_index(drop = True).drop([10, 12]).reset_index(drop = True)

accent6_185 = accent6_only[accent6_only.code == 185].reset_index(drop = True)

accent6_186 = accent6_only[accent6_only.code == 186].reset_index(drop = True).drop([1, 2, 7, 15, 18]).reset_index(drop = True)

# %% [markdown]
# ## Print ACCENT Output to Identify Dictionary Improvements

# %%
for i in range(len(accent6_1821)):
    parsed_output(accent6_1821, i)
    display(i)
# Out:
# 'AID = 22716179'
# 'Code = 1821'
# 'Text = "A black leader from the township of Soweto asserted today that two black policemen raped a girl as she returned home from school this week.'
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('NP', [Tree('NP', [Tree('DT', ['A']), Tree('JJ', ['black']), Tree('NN', ['leader'])]), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['township'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Soweto'])])])])])]), Tree('VP', [Tree('VBD', ['asserted']), Tree('NP-TMP', [Tree('NN', ['today'])]), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['that'])]), Tree('S', [Tree('NP', [Tree('CD', ['two']), Tree('JJ', ['black']), Tree('NNS', ['policemen'])]), Tree('VP', [Tree('VBD', ['raped']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['girl'])]), Tree('SBAR', [Tree('IN', ['as']), Tree('S', [Tree('NP', [Tree('PRP', ['she'])]), Tree('VP', [Tree('VBD', ['returned']), Tree('NP', [Tree('NN', ['home'])]), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('NN', ['school'])])]), Tree('NP-TMP', [Tree('DT', ['this']), Tree('NN', ['week'])])])])])])])])]), Tree('.', ['.'])])])
# 0
# 'AID = 22765423'
# 'Code = 1821'
# 'Text = It was filed by Representative Ron Dellums, Democrat of California, suing as a private citizen; Myrna Cunningham, who said she was raped in Nicaragua by rebels, and Eleanor Ginsburg, who said United States paramilitary training took place near her Florida home."'
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('PRP', ['It'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['filed']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NNP', ['Representative']), Tree('NNP', ['Ron']), Tree('NNP', ['Dellums'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('NNP', ['Democrat'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['California'])])])]), Tree(',', [',']), Tree('VP', [Tree('VBG', ['suing']), Tree('PP', [Tree('IN', ['as']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['private']), Tree('NN', ['citizen'])])])])]), Tree(':', [';']), Tree('NP', [Tree('NP', [Tree('NNP', ['Myrna']), Tree('NNP', ['Cunningham'])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['she'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['raped']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Nicaragua'])])]), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NNS', ['rebels'])])])])])])])])])])]), Tree(',', [',']), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('NNP', ['Eleanor']), Tree('NNP', ['Ginsburg'])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NNP', ['United']), Tree('NNPS', ['States']), Tree('JJ', ['paramilitary']), Tree('NN', ['training'])]), Tree('VP', [Tree('VBD', ['took']), Tree('NP', [Tree('NP', [Tree('NN', ['place'])]), Tree('PP', [Tree('IN', ['near']), Tree('NP', [Tree('PRP$', ['her']), Tree('NNP', ['Florida']), Tree('NN', ['home'])])])])])])])])])])])])])])]), Tree('.', ['.']), Tree("''", ["''"])])])
# 1
# 'AID = 22784158'
# 'Code = 1821'
# 'Text = "A nun was raped in the basement of a Manhattan convent late yesterday afternoon by a former handyman at the convent who last night surrendered to authorities, the police said.\\nThe suspect, identified as Mauricio Espinal, 26 years old, of 1274 Fifth Avenue, turned himself in at the 23rd Precinct station house on East 102d Street at 9:45 P.M..\\n\'\'He knew were were looking for him,\'\' said Sgt. Edward Burns, a spokesman for the police department.\\nSergeant Burns said the rape occurred at the convent at 5 P.M.,'
# Tree('ROOT', [Tree('FRAG', [Tree('NP', [Tree('NP', [Tree('``', ['``']), Tree('DT', ['A']), Tree('NN', ['nun'])]), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['raped']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['basement'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['a']), Tree('NNP', ['Manhattan']), Tree('NN', ['convent'])])]), Tree('NP-TMP', [Tree('JJ', ['late']), Tree('NN', ['yesterday'])])])]), Tree('NP-TMP', [Tree('NN', ['afternoon'])]), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['former']), Tree('NN', ['handyman'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['convent'])]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('NP-TMP', [Tree('JJ', ['last']), Tree('NN', ['night'])]), Tree('VP', [Tree('VBD', ['surrendered']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NNS', ['authorities'])])]), Tree(',', [',']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police'])]), Tree('VP', [Tree('VBD', ['said'])])])])])])])])])])])])])])]), Tree('.', ['.'])]), Tree('X', [Tree('X', [Tree('SYM', ['\\'])]), Tree('NP', [Tree('NP', [Tree('NNP', ['nThe']), Tree('NN', ['suspect'])]), Tree(',', [',']), Tree('VP', [Tree('VBN', ['identified']), Tree('PP', [Tree('IN', ['as']), Tree('NP', [Tree('NP', [Tree('NNP', ['Mauricio']), Tree('NNP', ['Espinal'])]), Tree(',', [',']), Tree('ADJP', [Tree('NP', [Tree('CD', ['26']), Tree('NNS', ['years'])]), Tree('JJ', ['old'])]), Tree(',', [',']), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('CD', ['1274']), Tree('NNP', ['Fifth']), Tree('NNP', ['Avenue'])]), Tree(',', [',']), Tree('VP', [Tree('VBD', ['turned']), Tree('NP', [Tree('PRP', ['himself'])]), Tree('PRT', [Tree('RP', ['in'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['23rd']), Tree('NNP', ['Precinct']), Tree('NN', ['station']), Tree('NN', ['house'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('NNP', ['East']), Tree('NNP', ['102d']), Tree('NNP', ['Street'])]), Tree('X', [Tree('X', [Tree('ADVP', [Tree('IN', ['at'])]), Tree('NP', [Tree('CD', ['9:45']), Tree('NN', ['P.M.'])]), Tree('.', ['.'])]), Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])])]), Tree('SBAR', [Tree('SBAR', [Tree('SINV', [Tree('``', ['``']), Tree('S', [Tree('NP', [Tree('PRP', ['He'])]), Tree('VP', [Tree('VBD', ['knew']), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VBG', ['looking']), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('PRP', ['him'])])])])])])])])])]), Tree(',', [',']), Tree("''", ["''"]), Tree('VP', [Tree('VBD', ['said'])]), Tree('NP', [Tree('NP', [Tree('NNP', ['Sgt.']), Tree('NNP', ['Edward']), Tree('NNP', ['Burns'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['spokesman'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police']), Tree('NN', ['department'])])])])]), Tree('.', ['.'])])]), Tree('SBAR', [Tree('X', [Tree('SYM', ['\\'])]), Tree('S', [Tree('NP', [Tree('NNP', ['nSergeant']), Tree('NNP', ['Burns'])]), Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['rape'])]), Tree('VP', [Tree('VBD', ['occurred']), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['convent'])])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('CD', ['5']), Tree('NN', ['P.M.'])])])])])])])])])])])])])])]), Tree(',', [','])])])])])])])])])])
# 2
# 'AID = 23005041'
# 'Code = 1821'
# 'Text = In another case, two assailants, after having met a young woman at a campus party, raped her in a nearby residence hall.'
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('DT', ['another']), Tree('NN', ['case'])])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('CD', ['two']), Tree('NNS', ['assailants'])]), Tree(',', [',']), Tree('PP', [Tree('IN', ['after']), Tree('S', [Tree('VP', [Tree('VBG', ['having']), Tree('VP', [Tree('VBN', ['met']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['young']), Tree('NN', ['woman'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['campus']), Tree('NN', ['party'])])])])])])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['raped']), Tree('NP', [Tree('PRP', ['her'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['nearby']), Tree('NN', ['residence']), Tree('NN', ['hall'])])])]), Tree('.', ['.'])])])
# 3
# 'AID = 23136784'
# 'Code = 1821'
# 'Text = The youths then beat the man on the head and upper body with bottles and their fists, took $25 from him, slit his pants with a razor and sexually assaulted him with a stick, the police said.'
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('DT', ['The']), Tree('NNS', ['youths'])]), Tree('ADVP', [Tree('RB', ['then'])]), Tree('VP', [Tree('VP', [Tree('VBD', ['beat']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['man'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['head'])]), Tree('CC', ['and']), Tree('NP', [Tree('JJ', ['upper']), Tree('NN', ['body'])])])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('NP', [Tree('NNS', ['bottles'])]), Tree('CC', ['and']), Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['fists'])])])])]), Tree(',', [',']), Tree('VP', [Tree('VBD', ['took']), Tree('NP', [Tree('$', ['$']), Tree('CD', ['25'])]), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('PRP', ['him'])])])]), Tree(',', [',']), Tree('VP', [Tree('VBD', ['slit']), Tree('NP', [Tree('PRP$', ['his']), Tree('NNS', ['pants'])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['razor'])])])]), Tree('CC', ['and']), Tree('VP', [Tree('ADVP', [Tree('RB', ['sexually'])]), Tree('VBD', ['assaulted']), Tree('NP', [Tree('PRP', ['him'])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['stick'])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police'])]), Tree('VP', [Tree('VBD', ['said'])]), Tree('.', ['.'])])])
# 4
# 'AID = 23199217'
# 'Code = 1821'
# 'Text = "A Manhattan federal appeals court on Jul 28, 1992 criticized the New York City Police Department for its apparent discrimination against Karen Sorlucco, who had charged another officer with raping her at gunpoint in 1983.'
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('NP', [Tree('NP', [Tree('DT', ['A']), Tree('NNP', ['Manhattan']), Tree('JJ', ['federal']), Tree('NNS', ['appeals']), Tree('NN', ['court'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NNP', ['Jul']), Tree('CD', ['28']), Tree(',', [',']), Tree('CD', ['1992'])])])]), Tree('VP', [Tree('VBD', ['criticized']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['New']), Tree('NNP', ['York']), Tree('NNP', ['City']), Tree('NNP', ['Police']), Tree('NNP', ['Department'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('PRP$', ['its']), Tree('JJ', ['apparent']), Tree('NN', ['discrimination'])])])]), Tree('PP', [Tree('IN', ['against']), Tree('NP', [Tree('NP', [Tree('NNP', ['Karen']), Tree('NNP', ['Sorlucco'])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['charged']), Tree('NP', [Tree('DT', ['another']), Tree('NN', ['officer'])]), Tree('PP', [Tree('IN', ['with']), Tree('S', [Tree('VP', [Tree('VBG', ['raping']), Tree('NP', [Tree('PRP$', ['her'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('NN', ['gunpoint'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1983'])])])])])])])])])])])])])])]), Tree('.', ['.'])])])
# 5
# 'AID = 23507977'
# 'Code = 1821'
# 'Text = Gordon then shot Ms. Mauzon in the head, forced the other women to remove their clothes and sexually assaulted them, eventually slashing Zakkiyhah Holliman, 18, to death and bludgeoning her twin, Hadiyah, with a hammer, the police said.\\nThe police said their account was based on interviews with Latisha Crite, 19, who fled by jumping from a window.'
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NNP', ['Gordon'])]), Tree('ADVP', [Tree('RB', ['then'])]), Tree('VP', [Tree('VP', [Tree('VBD', ['shot']), Tree('NP', [Tree('NP', [Tree('NNP', ['Ms.']), Tree('NNP', ['Mauzon'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['head'])])])])]), Tree(',', [',']), Tree('VP', [Tree('VBD', ['forced']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['other']), Tree('NNS', ['women'])]), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['remove']), Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['clothes'])])])])])]), Tree('CC', ['and']), Tree('VP', [Tree('ADVP', [Tree('RB', ['sexually'])]), Tree('VBD', ['assaulted']), Tree('NP', [Tree('PRP', ['them'])]), Tree(',', [',']), Tree('S', [Tree('VP', [Tree('VP', [Tree('ADVP', [Tree('RB', ['eventually'])]), Tree('VBG', ['slashing']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NNP', ['Zakkiyhah']), Tree('NNP', ['Holliman'])]), Tree(',', [',']), Tree('NP', [Tree('CD', ['18'])]), Tree(',', [','])]), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NN', ['death'])])])])]), Tree('CC', ['and']), Tree('VP', [Tree('VBG', ['bludgeoning']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('PRP$', ['her']), Tree('NN', ['twin'])]), Tree(',', [',']), Tree('NP', [Tree('NNP', ['Hadiyah'])]), Tree(',', [','])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['hammer'])])]), Tree(',', [',']), Tree('SBAR', [Tree('FRAG', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police'])]), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('VBD', ['said'])])])]), Tree('.', ['.'])]), Tree('X', [Tree('X', [Tree('SYM', ['\\'])]), Tree('NP', [Tree('NP', [Tree('NN', ['nThe']), Tree('NNS', ['police'])]), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP$', ['their']), Tree('NN', ['account'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['based']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NNS', ['interviews'])])])])])])])])])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('NP', [Tree('NNP', ['Latisha']), Tree('NNP', ['Crite'])]), Tree(',', [',']), Tree('NP', [Tree('CD', ['19'])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['fled']), Tree('PP', [Tree('IN', ['by']), Tree('S', [Tree('VP', [Tree('VBG', ['jumping']), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['window'])])])])])])])])])])])])])])])])])])])])]), Tree('.', ['.'])])])
# 6
# 'AID = 23517569'
# 'Code = 1821'
# 'Text = But the law would make untenable the defense that 14 years ago freed James L. Morrow, a former corrections officer accused of raping an inmate at Bedford Hills.'
# Tree('ROOT', [Tree('S', [Tree('CC', ['But']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['law'])]), Tree('VP', [Tree('MD', ['would']), Tree('VP', [Tree('VB', ['make']), Tree('S', [Tree('ADJP', [Tree('JJ', ['untenable'])]), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['defense'])]), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['that'])]), Tree('S', [Tree('ADVP', [Tree('NP', [Tree('CD', ['14']), Tree('NNS', ['years'])]), Tree('IN', ['ago'])]), Tree('VP', [Tree('VBN', ['freed']), Tree('NP', [Tree('NP', [Tree('NNP', ['James']), Tree('NNP', ['L.']), Tree('NNP', ['Morrow'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['former']), Tree('NNS', ['corrections']), Tree('NN', ['officer'])]), Tree('VP', [Tree('VBN', ['accused']), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('VP', [Tree('VBG', ['raping']), Tree('NP', [Tree('DT', ['an']), Tree('NN', ['inmate'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NNP', ['Bedford']), Tree('NNP', ['Hills'])])])])])])])])])])])])])])])]), Tree('.', ['.'])])])
# 7
# 'AID = 23517569'
# 'Code = 1821'
# "Text = He said a deputy warden and a corrections officer at the women's prison in Niantic were charged recently with sexual assault of the same inmate."
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('PRP', ['He'])]), Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['deputy']), Tree('NN', ['warden'])]), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NNS', ['corrections']), Tree('NN', ['officer'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNS', ['women']), Tree('POS', ["'s"])]), Tree('NN', ['prison'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Niantic'])])])])])])]), Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VBN', ['charged']), Tree('ADVP', [Tree('RB', ['recently'])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('NP', [Tree('JJ', ['sexual']), Tree('NN', ['assault'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['same']), Tree('NN', ['inmate'])])])])])])])])])]), Tree('.', ['.'])])])
# 8
# 'AID = 23527647'
# 'Code = 1821'
# 'Text = The woman told the police that she was raped by two male inmates  when she was changing clothes to leave the jail.'
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('DT', ['The']), Tree('NN', ['woman'])]), Tree('VP', [Tree('VBD', ['told']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police'])]), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP', [Tree('PRP', ['she'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['raped']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('CD', ['two']), Tree('JJ', ['male']), Tree('NNS', ['inmates'])]), Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['when'])]), Tree('S', [Tree('NP', [Tree('PRP', ['she'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBG', ['changing']), Tree('NP', [Tree('NNS', ['clothes'])]), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['leave']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['jail'])])])])])])])])])])])])])])])]), Tree('.', ['.'])])])
# 9
# 'AID = 23567161'
# 'Code = 1821'
# 'Text = "A former high school track coach was arrested today in connection with the rape of a Chabot College student, one of a series of attacks in the San Francisco Bay area attributed to a serial rapist.\\nThe suspect, Tony Lawayne Ransom, 47, of San Leandro, was arrested at his home, the police said.\\nMr.'
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('NP', [Tree('DT', ['A']), Tree('JJ', ['former']), Tree('JJ', ['high']), Tree('NN', ['school']), Tree('NN', ['track']), Tree('NN', ['coach'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['arrested']), Tree('NP-TMP', [Tree('NN', ['today'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NN', ['connection'])])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['rape'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NNP', ['Chabot']), Tree('NNP', ['College']), Tree('NN', ['student'])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('NP', [Tree('CD', ['one'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['series'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('NNS', ['attacks'])]), Tree('PP', [Tree('IN', ['in']), Tree('FRAG', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['San']), Tree('NNP', ['Francisco']), Tree('NNP', ['Bay']), Tree('NN', ['area'])]), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('VBD', ['attributed']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['serial']), Tree('NN', ['rapist'])])])])])]), Tree('.', ['.'])])])]), Tree('SBAR', [Tree('S', [Tree('SBAR', [Tree('X', [Tree('SYM', ['\\'])]), Tree('S', [Tree('NP', [Tree('NP', [Tree('NNP', ['nThe']), Tree('NN', ['suspect'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NNP', ['Tony']), Tree('NNP', ['Lawayne']), Tree('NNP', ['Ransom'])]), Tree(',', [',']), Tree('NP', [Tree('CD', ['47'])]), Tree(',', [','])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['San']), Tree('NNP', ['Leandro'])])])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['arrested']), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('PRP$', ['his']), Tree('NN', ['home'])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police'])]), Tree('VP', [Tree('VBD', ['said'])])])])])])]), Tree('.', ['.'])])]), Tree('S', [Tree('VP', [Tree('SYM', ['\\']), Tree('NP', [Tree('NN', ['nMr'])])])])])])])])])])]), Tree('.', ['.'])])])
# 10
# 'AID = 23614872'
# 'Code = 1821'
# "Text = \\n\\n\\nMaureen Kanka, who campaigned for the law after her 7-year old daughter Megan was raped and murdered by a paroled convict in her neighborhood in 1994, said at a seminar on child abuse today that swift and full prosecutions will reduce harassment of parolees.\\n\\n\\n''I"
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])]), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('SYM', ['\\']), Tree('NP', [Tree('NNP', ['nMaureen']), Tree('NNP', ['Kanka'])])])])])])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['campaigned']), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['law'])])]), Tree('SBAR', [Tree('IN', ['after']), Tree('S', [Tree('NP', [Tree('NP', [Tree('PRP$', ['her']), Tree('JJ', ['7-year']), Tree('JJ', ['old']), Tree('NN', ['daughter'])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NNP', ['Megan'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['raped']), Tree('CC', ['and']), Tree('VBN', ['murdered']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['paroled'])])])])])])])]), Tree('VP', [Tree('VB', ['convict']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('PRP$', ['her']), Tree('NN', ['neighborhood'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1994'])])])])])])])])])])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['said']), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['seminar'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NN', ['child'])])])])]), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('NN', ['abuse']), Tree('NN', ['today'])]), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['that'])]), Tree('S', [Tree('NP', [Tree('NP', [Tree('NN', ['swift'])]), Tree('CC', ['and']), Tree('NP', [Tree('JJ', ['full']), Tree('NNS', ['prosecutions'])])]), Tree('VP', [Tree('MD', ['will']), Tree('VP', [Tree('VB', ['reduce']), Tree('NP', [Tree('NP', [Tree('NN', ['harassment'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNS', ['parolees'])])])])])])])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])]), Tree('NP', [Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])]), Tree('``', ['``']), Tree('NP', [Tree('PRP', ['I'])])])])])])])
# 11
# 'AID = 23653242'
# 'Code = 1821'
# 'Text = Civil rights and minority groups had expressed concern about stepping up a police presence because of often-strained relations among young minority students and police officers.\\n\\n\\nBut the Division of School Safety has been the subject of no fewer than seven investigations since 1971 by the board, city and outside auditors, all of which found lapses in training, recruitment and discipline.\\nOver the years, there have been several incidents in which safety officers have been arrested on charges of sexually assaulting students or possessing drugs.\\nA high-ranking school administration official said there were no plans to dismiss any of the current safety officers,'
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('JJ', ['Civil']), Tree('NNS', ['rights']), Tree('CC', ['and']), Tree('NN', ['minority']), Tree('NNS', ['groups'])]), Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['expressed']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('NN', ['concern'])]), Tree('PP', [Tree('IN', ['about']), Tree('S', [Tree('VP', [Tree('VBG', ['stepping']), Tree('PRT', [Tree('RP', ['up'])]), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['police']), Tree('NN', ['presence'])]), Tree('PP', [Tree('IN', ['because']), Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('JJ', ['often-strained']), Tree('NNS', ['relations'])]), Tree('PP', [Tree('IN', ['among']), Tree('NP', [Tree('JJ', ['young']), Tree('NN', ['minority']), Tree('NNS', ['students']), Tree('CC', ['and']), Tree('NNS', ['police']), Tree('NNS', ['officers'])])])])])])])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NP', [Tree('NN', ['nBut'])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['Division'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['School']), Tree('NNP', ['Safety'])])])]), Tree('VP', [Tree('VBZ', ['has']), Tree('VP', [Tree('VBN', ['been']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['subject'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('QP', [Tree('DT', ['no']), Tree('JJR', ['fewer']), Tree('IN', ['than']), Tree('CD', ['seven'])]), Tree('NNS', ['investigations'])])])]), Tree('SBAR', [Tree('IN', ['since']), Tree('S', [Tree('NP', [Tree('NP', [Tree('CD', ['1971'])]), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['board'])]), Tree(',', [',']), Tree('NP', [Tree('NN', ['city'])]), Tree('CC', ['and']), Tree('NP', [Tree('JJ', ['outside']), Tree('NNS', ['auditors'])])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('DT', ['all']), Tree('WHPP', [Tree('IN', ['of']), Tree('WHNP', [Tree('WDT', ['which'])])])]), Tree('S', [Tree('VP', [Tree('VBD', ['found']), Tree('NP', [Tree('NNS', ['lapses'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NN', ['training']), Tree(',', [',']), Tree('NN', ['recruitment']), Tree('CC', ['and']), Tree('NN', ['discipline'])])])])])]), Tree('.', ['.'])])])]), Tree('VP', [Tree('SYM', ['\\']), Tree('NP', [Tree('NNP', ['nOver'])])])])])])])])])]), Tree('NP-TMP', [Tree('DT', ['the']), Tree('NNS', ['years'])]), Tree('PRN', [Tree(',', [',']), Tree('S', [Tree('NP', [Tree('EX', ['there'])]), Tree('VP', [Tree('VBP', ['have']), Tree('VP', [Tree('VBN', ['been']), Tree('NP', [Tree('NP', [Tree('JJ', ['several']), Tree('NNS', ['incidents'])]), Tree('SBAR', [Tree('WHPP', [Tree('IN', ['in']), Tree('WHNP', [Tree('WDT', ['which'])])]), Tree('FRAG', [Tree('NP', [Tree('NP', [Tree('NN', ['safety']), Tree('NNS', ['officers'])]), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('VBP', ['have']), Tree('VP', [Tree('VBN', ['been']), Tree('VP', [Tree('VBN', ['arrested']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('NNS', ['charges'])]), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('VP', [Tree('VP', [Tree('ADVP', [Tree('RB', ['sexually'])]), Tree('VBG', ['assaulting']), Tree('NP', [Tree('NNS', ['students'])])]), Tree('CC', ['or']), Tree('VP', [Tree('VBG', ['possessing']), Tree('NP', [Tree('NNS', ['drugs'])])])])])])])])])])])])]), Tree('.', ['.'])]), Tree('X', [Tree('X', [Tree('SYM', ['\\'])]), Tree('NP', [Tree('NP', [Tree('NN', ['nA'])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('JJ', ['high-ranking']), Tree('NN', ['school']), Tree('NN', ['administration']), Tree('NN', ['official'])]), Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('EX', ['there'])]), Tree('VP', [Tree('VBD', ['were']), Tree('NP', [Tree('DT', ['no']), Tree('NNS', ['plans']), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['dismiss ...
# 12
# 'AID = 23673222'
# 'Code = 1821'
# 'Text = "The mother of a 13-year old boy who says he was sexually assaulted by a Yale professor has sued him, the university and the New Haven Board of Education.\\n  The suit claims that Antonio Lasaga, a geology professor, abused the boy while mentoring him in a New Haven public school program.'
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['The']), Tree('NN', ['mother'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['13-year']), Tree('JJ', ['old']), Tree('NN', ['boy'])]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBZ', ['says']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['was']), Tree('ADVP', [Tree('RB', ['sexually'])]), Tree('VP', [Tree('VBN', ['assaulted']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('DT', ['a']), Tree('NNP', ['Yale']), Tree('NN', ['professor'])])])])])])])])])])])])]), Tree('VP', [Tree('VBZ', ['has']), Tree('VP', [Tree('VBN', ['sued']), Tree('NP', [Tree('PRP', ['him'])])])])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['university'])]), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NAC', [Tree('NNP', ['New']), Tree('NNP', ['Haven']), Tree('NNP', ['Board']), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Education'])]), Tree('.', ['.'])])]), Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('DT', ['The']), Tree('NN', ['suit'])])])]), Tree('VP', [Tree('VBZ', ['claims']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP', [Tree('NP', [Tree('NNP', ['Antonio']), Tree('NNP', ['Lasaga'])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['geology']), Tree('NN', ['professor'])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['abused']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['boy'])]), Tree('PP', [Tree('IN', ['while']), Tree('S', [Tree('VP', [Tree('VBG', ['mentoring']), Tree('NP', [Tree('PRP', ['him'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('DT', ['a']), Tree('ADJP', [Tree('NNP', ['New']), Tree('NNP', ['Haven'])]), Tree('JJ', ['public']), Tree('NN', ['school']), Tree('NN', ['program'])])])])])])])])])]), Tree('.', ['.'])])])
# 13
# 'AID = 23686162'
# 'Code = 1821'
# "Text = ''Albanian criminal gangs go over to burn Serbian churches and the roots of our religion, raping Serbs and kidnapping them and burning their houses."
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('NP', [Tree('JJ', ['Albanian']), Tree('JJ', ['criminal']), Tree('NNS', ['gangs'])]), Tree('VP', [Tree('VBP', ['go']), Tree('ADJP', [Tree('IN', ['over']), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['burn']), Tree('NP', [Tree('NP', [Tree('JJ', ['Serbian']), Tree('NNS', ['churches'])]), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNS', ['roots'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('PRP$', ['our']), Tree('NN', ['religion'])])])])])])])])]), Tree(',', [',']), Tree('S', [Tree('VP', [Tree('VP', [Tree('VBG', ['raping']), Tree('S', [Tree('NP', [Tree('NNS', ['Serbs']), Tree('CC', ['and']), Tree('NN', ['kidnapping'])]), Tree('NP', [Tree('PRP', ['them'])])])]), Tree('CC', ['and']), Tree('VP', [Tree('VBG', ['burning']), Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['houses'])])])])])]), Tree('.', ['.'])])])
# 14
# 'AID = 23767317'
# 'Code = 1821'
# 'Text = He also faces charges in State Superior Court that he sexually assaulted a 13-year old New Haven boy whom he had taught as part of a mentoring program.'
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('PRP', ['He'])]), Tree('ADVP', [Tree('RB', ['also'])]), Tree('VP', [Tree('VBZ', ['faces']), Tree('NP', [Tree('NNS', ['charges'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['State']), Tree('NNP', ['Superior']), Tree('NNP', ['Court'])])]), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('ADVP', [Tree('RB', ['sexually'])]), Tree('VBD', ['assaulted']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['13-year']), Tree('ADJP', [Tree('JJ', ['old']), Tree('NNP', ['New']), Tree('NNP', ['Haven'])]), Tree('NN', ['boy'])]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['whom'])]), Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['taught']), Tree('PP', [Tree('IN', ['as']), Tree('NP', [Tree('NP', [Tree('NN', ['part'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['mentoring']), Tree('NN', ['program'])])])])])])])])])])])])]), Tree('.', ['.'])])])
# 15
# 'AID = 23817693'
# 'Code = 1821'
# 'Text = "A high school student here has been accused of sexually assaulting a classmate -- an awful allegation for any community, but particularly for this suburban enclave, which is still smarting over a highly publicized assault case more than a decade ago.\\n\\n\\nIn 1989, bucolic Glen Ridge, where every street is graced by a gas-fueled lamplight, was rocked when a mildly retarded 17-year old girl was sexually assaulted by a group of Glen Ridge High School athletes.'
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('S', [Tree('NP', [Tree('DT', ['A']), Tree('JJ', ['high']), Tree('NN', ['school']), Tree('NN', ['student'])]), Tree('ADVP', [Tree('RB', ['here'])]), Tree('VP', [Tree('VBZ', ['has']), Tree('VP', [Tree('VBN', ['been']), Tree('VP', [Tree('VBN', ['accused']), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('ADVP', [Tree('RB', ['sexually'])]), Tree('VP', [Tree('VBG', ['assaulting']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['classmate'])])])])])])])])]), Tree(':', ['--']), Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['awful']), Tree('NN', ['allegation'])]), Tree('PP', [Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['any']), Tree('NN', ['community'])])]), Tree(',', [',']), Tree('CC', ['but']), Tree('RB', ['particularly']), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['this']), Tree('JJ', ['suburban']), Tree('NN', ['enclave'])])])]), Tree(',', [',']), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['which'])]), Tree('S', [Tree('VP', [Tree('VBZ', ['is']), Tree('ADVP', [Tree('RB', ['still'])]), Tree('VP', [Tree('VBG', ['smarting']), Tree('PP', [Tree('IN', ['over']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('ADJP', [Tree('RB', ['highly']), Tree('VBN', ['publicized'])]), Tree('NN', ['assault']), Tree('NN', ['case'])]), Tree('ADVP', [Tree('NP', [Tree('QP', [Tree('JJR', ['more']), Tree('IN', ['than']), Tree('DT', ['a'])]), Tree('NN', ['decade'])]), Tree('RB', ['ago'])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NP', [Tree('NN', ['nIn']), Tree('CD', ['1989'])]), Tree(',', [',']), Tree('NP', [Tree('JJ', ['bucolic']), Tree('NNP', ['Glen']), Tree('NNP', ['Ridge'])]), Tree(',', [',']), Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['where'])]), Tree('S', [Tree('NP', [Tree('DT', ['every']), Tree('NN', ['street'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('VP', [Tree('VBN', ['graced']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['gas-fueled']), Tree('NN', ['lamplight'])])])])])])])])])])])])])])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['rocked']), Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['when'])]), Tree('S', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('ADJP', [Tree('RB', ['mildly']), Tree('VBN', ['retarded'])])]), Tree('ADJP', [Tree('JJ', ['17-year']), Tree('JJ', ['old'])])]), Tree('NP', [Tree('NN', ['girl'])])]), Tree('VP', [Tree('VBD', ['was']), Tree('ADVP', [Tree('RB', ['sexually'])]), Tree('VP', [Tree('VBN', ['assaulted']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['group'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Glen']), Tree('NNP', ['Ridge']), Tree('NNP', ['High']), Tree('NNP', ['School']), Tree('NNS', ['athletes'])])])])])])])])])])])]), Tree('.', ['.'])])])
# 16
# 'AID = 23837729'
# 'Code = 1821'
# "Text = Mr. Trump said he wanted the ''criminals of every age'' who were accused of beating and raping a jogger in Central Park 12 days earlier ''to be afraid.''"
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NNP', ['Mr.']), Tree('NNP', ['Trump'])]), Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['wanted']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('``', ['``']), Tree('NNS', ['criminals'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['every']), Tree('NN', ['age'])]), Tree("''", ["''"]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VP', [Tree('VBN', ['accused']), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['beating'])])])]), Tree('CC', ['and']), Tree('VP', [Tree('VBG', ['raping']), Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['jogger'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('NNP', ['Central']), Tree('NNP', ['Park'])]), Tree('ADVP', [Tree('NP', [Tree('CD', ['12']), Tree('NNS', ['days'])]), Tree('RBR', ['earlier'])])])])]), Tree('``', ['``']), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('ADJP', [Tree('JJ', ['afraid'])])])])])])])])])])])])])])])])]), Tree('.', ['.']), Tree("''", ["''"])])])
# 17
# 'AID = 23843674'
# 'Code = 1821'
# 'Text = "A Roman Catholic priest was arrested yesterday in Texas on charges that two years ago he raped a woman on a couch in a Brooklyn rectory, where she had gone for advice about annulling her marriage, the authorities said.\\n\\nChurch officials in Brooklyn did not notify law enforcement officials of the woman\'s accusations against the priest, the Rev. Cyriacus Udegbulem, in 2000, and instead encouraged her to do so herself, a church spokesman said yesterday.'
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('S', [Tree('NP', [Tree('DT', ['A']), Tree('JJ', ['Roman']), Tree('JJ', ['Catholic']), Tree('NN', ['priest'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['arrested']), Tree('NP-TMP', [Tree('NN', ['yesterday'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Texas'])])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('NNS', ['charges'])]), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['that'])]), Tree('S', [Tree('ADVP', [Tree('NP', [Tree('CD', ['two']), Tree('NNS', ['years'])]), Tree('IN', ['ago'])]), Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['raped']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['woman'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['couch'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NNP', ['Brooklyn']), Tree('NN', ['rectory'])]), Tree(',', [',']), Tree('S', [Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['where'])]), Tree('S', [Tree('NP', [Tree('PRP', ['she'])]), Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['gone']), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NN', ['advice'])])]), Tree('PP', [Tree('IN', ['about']), Tree('S', [Tree('VP', [Tree('VBG', ['annulling']), Tree('NP', [Tree('PRP$', ['her']), Tree('NN', ['marriage'])])])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NNS', ['authorities'])]), Tree('VP', [Tree('VBD', ['said'])]), Tree('.', ['.'])])])])])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NN', ['nChurch']), Tree('NNS', ['officials'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Brooklyn'])])])])]), Tree('VP', [Tree('VBD', ['did']), Tree('RB', ['not']), Tree('VP', [Tree('VB', ['notify']), Tree('NP', [Tree('NP', [Tree('NN', ['law']), Tree('NN', ['enforcement']), Tree('NNS', ['officials'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['woman']), Tree('POS', ["'s"])]), Tree('NNS', ['accusations'])])])]), Tree('PP', [Tree('IN', ['against']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['priest'])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Rev.']), Tree('NNP', ['Cyriacus']), Tree('NNP', ['Udegbulem'])]), Tree(',', [','])])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['2000'])])])])])]), Tree(',', [',']), Tree('CC', ['and']), Tree('S', [Tree('ADVP', [Tree('RB', ['instead'])]), Tree('VP', [Tree('VBD', ['encouraged']), Tree('S', [Tree('NP', [Tree('PRP', ['her'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['do']), Tree('ADVP', [Tree('RB', ['so'])]), Tree('NP', [Tree('PRP', ['herself'])])])])])])])])])])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['church']), Tree('NN', ['spokesman'])]), Tree('VP', [Tree('VBD', ['said']), Tree('NP-TMP', [Tree('NN', ['yesterday'])])]), Tree('.', ['.'])])])
# 18
# 'AID = 23884652'
# 'Code = 1821'
# 'Text = He is accused of raping the student twice, once at Newton High School in Elmhurst in December and once near Forest Park in March, said Detective Cheryl Cox.'
# Tree('ROOT', [Tree('SINV', [Tree('S', [Tree('NP', [Tree('PRP', ['He'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('VP', [Tree('VBN', ['accused']), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('VP', [Tree('VBG', ['raping']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['student'])]), Tree('ADVP', [Tree('RB', ['twice'])]), Tree(',', [',']), Tree('ADVP', [Tree('RB', ['once'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('NNP', ['Newton']), Tree('NNP', ['High']), Tree('NNP', ['School'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Elmhurst'])])])])]), Tree('PP', [Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['December'])])]), Tree('CC', ['and']), Tree('PP', [Tree('ADVP', [Tree('RB', ['once'])]), Tree('IN', ['near']), Tree('NP', [Tree('NP', [Tree('NNP', ['Forest']), Tree('NNP', ['Park'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['March'])])])])])])])])])])])]), Tree(',', [',']), Tree('VP', [Tree('VBD', ['said'])]), Tree('NP', [Tree('NNP', ['Detective']), Tree('NNP', ['Cheryl']), Tree('NNP', ['Cox'])]), Tree('.', ['.'])])])
# 19
# 'AID = 23891790'
# 'Code = 1821'
# "Text = He detained Mr. Gauthe over a new accusation that back in the 1980's, the priest had raped a 12-year old sister of one of his altar-boy victims.\\n\\n\\n\\nLater, though, the state and the defense discovered a long-forgotten provision in Mr. Gauthe's plea bargain: immunity against further complaints on acts that had occurred before 1985."
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('PRP', ['He'])]), Tree('VP', [Tree('VBD', ['detained']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NNP', ['Mr.']), Tree('NNP', ['Gauthe'])]), Tree('PP', [Tree('IN', ['over']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['new']), Tree('NN', ['accusation'])]), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['that'])]), Tree('S', [Tree('ADVP', [Tree('RB', ['back']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('CD', ['1980']), Tree('POS', ["'s"])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['priest'])])])])]), Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['raped']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['12-year']), Tree('JJ', ['old']), Tree('NN', ['sister'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('CD', ['one'])])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('PRP$', ['his']), Tree('JJ', ['altar-boy']), Tree('NNS', ['victims'])])])])])])])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])]), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NN', ['nLater'])])])])]), Tree(',', [',']), Tree('ADVP', [Tree('RB', ['though'])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['state'])]), Tree('CC', ['and']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['defense'])])])])]), Tree('VP', [Tree('VBD', ['discovered']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['long-forgotten']), Tree('NN', ['provision'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NNP', ['Mr.']), Tree('NNP', ['Gauthe']), Tree('POS', ["'s"])]), Tree('NN', ['plea']), Tree('NN', ['bargain'])]), Tree(':', [':']), Tree('NP', [Tree('NP', [Tree('NN', ['immunity'])]), Tree('PP', [Tree('IN', ['against']), Tree('NP', [Tree('JJ', ['further']), Tree('NNS', ['complaints'])])])])])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('NNS', ['acts'])]), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['that'])]), Tree('S', [Tree('VP', [Tree('VBD', ['had']), Tree('VP', [Tree('VBN', ['occurred']), Tree('PP', [Tree('IN', ['before']), Tree('NP', [Tree('CD', ['1985'])])])])])])])])])])])])]), Tree('.', ['.'])])])
# 20
# 'AID = 23961369'
# 'Code = 1821'
# "Text = Despite the pressure on bishops over the last year to reveal the extent of the abuse, some refused to release the number of accusations or the names of the accused priests.\\n\\n\\nDECADES OF DAMAGEThe Sexual Abuse Scandal&lt;break/&gt;\\n\\n&lt;umient&gt;\\n&lt;uopts&gt;&lt;ety&gt;39&lt;/ety&gt;&lt;enum&gt;0&lt;/enum&gt;&lt;/uopts&gt;&lt;abstext&gt;\\n\\n Richard K. O'Connor says he was raped by three priests when he was 10."
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['Despite']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['pressure'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('NNS', ['bishops'])]), Tree('PP', [Tree('IN', ['over']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['last']), Tree('NN', ['year']), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['reveal']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['extent'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['abuse'])])])])])])])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['some'])]), Tree('VP', [Tree('VBD', ['refused']), Tree('S', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['release']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['number'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('NNS', ['accusations'])]), Tree('CC', ['or']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NNS', ['names'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('VBN', ['accused']), Tree('NNS', ['priests'])])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])])])])]), Tree('VP', [Tree('SYM', ['\\']), Tree('NP', [Tree('NNPS', ['nDECADES'])])])])])])])]), Tree('PP', [Tree('IN', ['OF']), Tree('NP', [Tree('NP', [Tree('NNP', ['DAMAGEThe']), Tree('NNP', ['Sexual']), Tree('NN', ['Abuse']), Tree('NN', ['Scandal'])]), Tree('PP', [Tree('NP', [Tree('NP', [Tree('JJR', ['<']), Tree('NN', ['break'])]), Tree('PRN', [Tree(':', ['/']), Tree('NP', [Tree('NP', [Tree('JJR', ['>'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])])]), Tree('NP', [Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])]), Tree('VP', [Tree('VBG', ['<']), Tree('NP', [Tree('JJ', ['umient']), Tree('JJR', ['>'])]), Tree('NP-TMP', [Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])]), Tree('VP', [Tree('VBG', ['<']), Tree('S', [Tree('NP', [Tree('NNS', ['uopts'])]), Tree('ADJP', [Tree('NP', [Tree('JJR', ['>'])]), Tree('JJR', ['<'])]), Tree('SBAR', [Tree('X', [Tree('X', [Tree('NP', [Tree('NP', [Tree('CD', ['ety']), Tree('JJR', ['>'])]), Tree('NP', [Tree('NP', [Tree('CD', ['39']), Tree('ADJP', [Tree('ADJP', [Tree('JJR', ['<'])]), Tree('PRN', [Tree(':', ['/']), Tree('S', [Tree('NP', [Tree('NP', [Tree('ADJP', [Tree('NP', [Tree('NN', ['ety'])]), Tree('JJR', ['>'])]), Tree('JJR', ['<']), Tree('NN', ['enum'])]), Tree('ADJP', [Tree('JJR', ['>'])])]), Tree('ADJP', [Tree('NP', [Tree('CD', ['0'])]), Tree('JJR', ['<'])])]), Tree(':', ['/'])])]), Tree('NN', ['enum'])]), Tree('ADJP', [Tree('ADJP', [Tree('NP', [Tree('JJR', ['>'])]), Tree('JJR', ['<'])]), Tree('PRN', [Tree(':', ['/']), Tree('S', [Tree('NP', [Tree('NNS', ['uopts'])]), Tree('ADJP', [Tree('JJR', ['>'])])])])])])]), Tree('NP', [Tree('JJR', ['<']), Tree('NN', ['abstext'])]), Tree('NP', [Tree('NP', [Tree('JJR', ['>'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])]), Tree('S', [Tree('NP', [Tree('NNP', ['Richard']), Tree('NNP', ['K.']), Tree('NNP', ["O'Connor"])]), Tree('VP', [Tree('VBZ', ['says']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['raped']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('CD', ['three']), Tree('NNS', ['priests'])]), Tree('SBAR', [Tree('WHADVP', [Tree('WRB', ['when'])]), Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['was']), Tree('NP', [Tree('CD', ['10'])])])])])])])])])])])])])])])])])])])])])])]), Tree('.', ['.'])])])
# 21
# 'AID = 23981957'
# 'Code = 1821'
# 'Text = "Prosecutors suddenly dropped charges against two Montclair High School football players accused of raping a schoolmate because they concluded that the sex was not forced or violent but consensual, people with knowledge of the case said yesterday.\\n\\nIt is not clear if the girl, a 15-year old sophomore, recanted her replacementinal charge that the boys kidnapped her and forced her to have sex in the back of a car,'
# Tree('ROOT', [Tree('S', [Tree('``', ['``']), Tree('NP', [Tree('NNS', ['Prosecutors'])]), Tree('ADVP', [Tree('RB', ['suddenly'])]), Tree('VP', [Tree('VBD', ['dropped']), Tree('NP', [Tree('NNS', ['charges'])]), Tree('PP', [Tree('IN', ['against']), Tree('NP', [Tree('NP', [Tree('CD', ['two']), Tree('NNP', ['Montclair']), Tree('NNP', ['High']), Tree('NNP', ['School']), Tree('NN', ['football']), Tree('NNS', ['players'])]), Tree('VP', [Tree('VBN', ['accused']), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('VP', [Tree('VBG', ['raping']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['schoolmate'])]), Tree('SBAR', [Tree('IN', ['because']), Tree('S', [Tree('NP', [Tree('PRP', ['they'])]), Tree('VP', [Tree('VBD', ['concluded']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('S', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['sex'])]), Tree('VP', [Tree('VBD', ['was']), Tree('RB', ['not']), Tree('VP', [Tree('VBN', ['forced'])])])]), Tree('CC', ['or']), Tree('S', [Tree('ADJP', [Tree('JJ', ['violent']), Tree('CC', ['but']), Tree('JJ', ['consensual'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('NNS', ['people'])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('NN', ['knowledge'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['case'])]), Tree('VP', [Tree('VBD', ['said']), Tree('NP-TMP', [Tree('NN', ['yesterday'])])])])])]), Tree('.', ['.']), Tree('NP', [Tree('NP', [Tree('NN', ['\\'])]), Tree('NP', [Tree('NN', ['n'])])])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NN', ['nIt'])])])])])]), Tree('VP', [Tree('VBZ', ['is']), Tree('RB', ['not']), Tree('ADJP', [Tree('JJ', ['clear'])]), Tree('SBAR', [Tree('IN', ['if']), Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['girl'])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['15-year']), Tree('JJ', ['old']), Tree('NN', ['sophomore'])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['recanted']), Tree('NP', [Tree('PRP$', ['her']), Tree('JJ', ['replacementinal']), Tree('NN', ['charge'])]), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP', [Tree('DT', ['the']), Tree('NNS', ['boys'])]), Tree('VP', [Tree('VP', [Tree('VBD', ['kidnapped']), Tree('NP', [Tree('PRP', ['her'])])]), Tree('CC', ['and']), Tree('VP', [Tree('VBD', ['forced']), Tree('S', [Tree('NP', [Tree('PRP', ['her'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['have']), Tree('NP', [Tree('NP', [Tree('NN', ['sex'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['back'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['car'])])])])])])])])])])])])])])])])]), Tree(',', [','])])])])])])])])])])])])])])])])
# 22
# 'AID = 24047881'
# 'Code = 1821'
# "Text = The scandal that erupted in 2003 prompted several investigations, the ouster of the school's four top commanders and new policies.\\n\\n\\nA separate court martial was under way on Saturday at the academy for a senior cadet accused of raping another cadet while on a diving club trip last year in New Mexico.\\nWitnesses testified at a preliminary hearing in November that the senior cadet, Benjamin Kuster, said he was drunk and may have mistaken the woman for his girlfriend."
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['The']), Tree('NN', ['scandal'])]), Tree('SBAR', [Tree('WHNP', [Tree('WDT', ['that'])]), Tree('S', [Tree('VP', [Tree('VBD', ['erupted']), Tree('SBAR', [Tree('SINV', [Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['2003'])])]), Tree('VP', [Tree('VBD', ['prompted'])]), Tree('NP', [Tree('NP', [Tree('JJ', ['several']), Tree('NNS', ['investigations'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['ouster'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['school']), Tree('POS', ["'s"])]), Tree('CD', ['four']), Tree('JJ', ['top']), Tree('NNS', ['commanders']), Tree('CC', ['and']), Tree('JJ', ['new']), Tree('NNS', ['policies'])])])])]), Tree('.', ['.'])])])])])])]), Tree('PRN', [Tree('S', [Tree('NP', [Tree('NP', [Tree('NN', ['\\']), Tree('NN', ['n'])]), Tree('NP', [Tree('CD', ['\\']), Tree('NN', ['n'])])]), Tree('VP', [Tree('VBG', ['\\']), Tree('NP', [Tree('NN', ['nA'])])])])]), Tree('NP', [Tree('JJ', ['separate']), Tree('NN', ['court']), Tree('NN', ['martial'])]), Tree('VP', [Tree('VP', [Tree('VBD', ['was']), Tree('PP', [Tree('IN', ['under']), Tree('NP', [Tree('NP', [Tree('NN', ['way'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('NNP', ['Saturday'])])])])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['academy'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['senior']), Tree('NN', ['cadet'])]), Tree('VP', [Tree('VBN', ['accused']), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('VP', [Tree('VBG', ['raping']), Tree('NP', [Tree('DT', ['another']), Tree('NN', ['cadet'])]), Tree('SBAR', [Tree('IN', ['while']), Tree('S', [Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['diving']), Tree('NN', ['club']), Tree('NN', ['trip'])])]), Tree('NP-TMP', [Tree('JJ', ['last']), Tree('NN', ['year'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('NNP', ['New']), Tree('NNP', ['Mexico']), Tree('.', ['.'])]), Tree('SBAR', [Tree('S', [Tree('VP', [Tree('SYM', ['\\']), Tree('NP', [Tree('NNS', ['nWitnesses'])])])])])])]), Tree('VP', [Tree('VBD', ['testified']), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['preliminary']), Tree('NN', ['hearing'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['November'])])])])]), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['senior']), Tree('NN', ['cadet'])]), Tree(',', [',']), Tree('NP', [Tree('NNP', ['Benjamin']), Tree('NNP', ['Kuster'])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['said']), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['he'])]), Tree('VP', [Tree('VBD', ['was']), Tree('ADJP', [Tree('JJ', ['drunk'])])])])])])])])])])])])])])])])])])])]), Tree('CC', ['and']), Tree('VP', [Tree('MD', ['may']), Tree('VP', [Tree('VB', ['have']), Tree('VP', [Tree('VBN', ['mistaken']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['woman'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('PRP$', ['his']), Tree('NN', ['girlfriend'])])])])])])])]), Tree('.', ['.'])])])
# 23

# %%
one_sentence_parser("A separate court martial was under way on Saturday at the academy for a senior cadet accused of raping another cadet while on a diving club trip last year in New Mexico.")
# Out:
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('DT', ['A']), Tree('JJ', ['separate']), Tree('NN', ['court']), Tree('NN', ['martial'])]), Tree('VP', [Tree('VBD', ['was']), Tree('ADVP', [Tree('IN', ['under']), Tree('NN', ['way']), Tree('PP', [Tree('IN', ['on']), Tree('NP-TMP', [Tree('NNP', ['Saturday'])]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['academy'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['senior']), Tree('NN', ['cadet'])])])])])])]), Tree('VP', [Tree('VBN', ['accused']), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('VP', [Tree('VBG', ['raping']), Tree('NP', [Tree('DT', ['another']), Tree('NN', ['cadet'])]), Tree('PP', [Tree('IN', ['while']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['diving']), Tree('NN', ['club']), Tree('NN', ['trip'])])])]), Tree('NP-TMP', [Tree('JJ', ['last']), Tree('NN', ['year'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['New']), Tree('NNP', ['Mexico'])])])])])])])]), Tree('.', ['.'])])])

# %% [markdown]
# ## NYTbd Sample 5 Run 2

# %%
petrarch5_run2_full = pd.read_stata("/Volumes/PartTime/Jonathan Bonaguro - Spring 2020/NYTbd sample 5/Sample5_run2/NYTbd_sample5_run2_events_text.dta")

# %%
# Convert Data Types to int32
petrarch5_run2_full['code'] = petrarch5_run2_full['code'].astype('int32')
petrarch5_run2_full['aid'] = petrarch5_run2_full['aid'].astype('int32')

# trim petrarch5_full down to relevant codes
petrarch5_run2 = petrarch5_run2_full[petrarch5_run2_full['code'].isin(relevant_codes)]

# %%
# set index on AID and Code
petrarch5_run2_index = petrarch5_run2.set_index(keys).index

# Produce df's of mutually exclusive events 
petrarch5_run2_only = petrarch5_run2[~petrarch5_run2_index.isin(petrarch5_index)]

# %%
petrarch5_run2_only
# Out:
#      code                                               text       aid
# 1    1823  In a separate incident , the police said , an ...  23550887
# 111  1711  Indian customs officials seized 21 tons of sil...  22373265
# 165  1823  In Tel Aviv , two Israelis were stabbed to dea...  23255640
# 194  1823  A Maryland laborer has been charged with beati...  23735670
# 202  1823  Two unidentified blacks beat a British mission...  22444326
# 354  1711  For example , the famous Benin bronzes were se...  23449664

# %%
len(petrarch5)
len(petrarch5_run2)
# Out:
# 24
# 27

# %%
relevant_aids = petrarch5_run2_only.aid.unique()

# %%
test = petrarch5[petrarch5['aid'].isin(relevant_aids)]

# %%
test
# Out:
#      code                                               text       aid
# 101   182  In Tel Aviv , two Israelis were stabbed to dea...  23255640
# 168   182  A Maryland laborer has been charged with beati...  23735670
# 386   182  In a separate incident , the police said , an ...  23550887

# %%
petrarch5_run2_only['parsed'] = core_parser(petrarch5_run2_only, 'text')
petrarch5_run2_only['dep'] = dep_parser(petrarch5_run2_only, 'text')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range(len(petrarch5_run2_only)):
    parsed_output(petrarch5_run2_only, i)
    display(i)
# Out:
# 'AID = 23550887'
# 'Code = 1823'
# 'Text = In a separate incident , the police said , an off-duty policeman was beaten to death early this morning by Protestant men outside a bar in the Protestant town of Ballymoney , north of Belfast .'
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['separate']), Tree('NN', ['incident'])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['police'])]), Tree('VP', [Tree('VBD', ['said']), Tree('PRN', [Tree(',', [',']), Tree('S', [Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['off-duty']), Tree('NN', ['policeman'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['beaten']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NN', ['death'])])]), Tree('NP-TMP', [Tree('RB', ['early']), Tree('DT', ['this']), Tree('NN', ['morning'])]), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('NNP', ['Protestant']), Tree('NNS', ['men'])]), Tree('PP', [Tree('IN', ['outside']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['bar'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['Protestant']), Tree('NN', ['town'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Ballymoney'])])])])])])])])])])])]), Tree(',', [','])]), Tree('NP', [Tree('NP', [Tree('NN', ['north'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Belfast'])])])])]), Tree('.', ['.'])])])
# 0
# 'AID = 22373265'
# 'Code = 1711'
# 'Text = Indian customs officials seized 21 tons of silver from smugglers during the first six months of 1980 , it was announced today .'
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('JJ', ['Indian']), Tree('NNS', ['customs']), Tree('NNS', ['officials'])]), Tree('VP', [Tree('VBD', ['seized']), Tree('NP', [Tree('NP', [Tree('CD', ['21']), Tree('NNS', ['tons'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['silver'])])])]), Tree('PP', [Tree('IN', ['from']), Tree('NP', [Tree('NNS', ['smugglers'])])]), Tree('PP', [Tree('IN', ['during']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['first']), Tree('CD', ['six']), Tree('NNS', ['months'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('CD', ['1980'])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('PRP', ['it'])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('VBN', ['announced']), Tree('NP-TMP', [Tree('NN', ['today'])])])]), Tree('.', ['.'])])])
# 1
# 'AID = 23255640'
# 'Code = 1823'
# 'Text = In Tel Aviv , two Israelis were stabbed to death by a young Palestinian on a knife-wielding rampage .'
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('NNP', ['Tel']), Tree('NNP', ['Aviv'])])]), Tree(',', [',']), Tree('NP', [Tree('CD', ['two']), Tree('NNPS', ['Israelis'])]), Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VBN', ['stabbed']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NN', ['death'])])]), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['young']), Tree('NN', ['Palestinian'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['knife-wielding']), Tree('NN', ['rampage'])])])])])])]), Tree('.', ['.'])])])
# 2
# 'AID = 23735670'
# 'Code = 1823'
# 'Text = A Maryland laborer has been charged with beating and stabbing to death a priest who surprised an intruder in the rectory of his church .'
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('DT', ['A']), Tree('NNP', ['Maryland']), Tree('NN', ['laborer'])]), Tree('VP', [Tree('VBZ', ['has']), Tree('VP', [Tree('VBN', ['been']), Tree('VP', [Tree('VBN', ['charged']), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('NN', ['beating'])])])])])])]), Tree('CC', ['and']), Tree('S', [Tree('VP', [Tree('VBG', ['stabbing']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NN', ['death'])])]), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['priest'])]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBD', ['surprised']), Tree('NP', [Tree('DT', ['an']), Tree('NN', ['intruder'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['rectory'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('PRP$', ['his']), Tree('NN', ['church'])])])])])])])])])])]), Tree('.', ['.'])])])
# 3
# 'AID = 22444326'
# 'Code = 1823'
# 'Text = Two unidentified blacks beat a British missionary couple to death in Zimbabwe last night , apparently in revenge for a South African raid into neighboring Mozambique , a church spokesman said today .'
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('NP', [Tree('CD', ['Two']), Tree('JJ', ['unidentified']), Tree('NNS', ['blacks'])]), Tree('VP', [Tree('VBD', ['beat']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['British']), Tree('JJ', ['missionary']), Tree('NN', ['couple'])]), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NN', ['death'])])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Zimbabwe'])])]), Tree('NP-TMP', [Tree('JJ', ['last']), Tree('NN', ['night'])]), Tree(',', [',']), Tree('PP', [Tree('ADVP', [Tree('RB', ['apparently'])]), Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('NN', ['revenge'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('ADJP', [Tree('JJ', ['South']), Tree('JJ', ['African'])]), Tree('NN', ['raid'])]), Tree('PP', [Tree('IN', ['into']), Tree('NP', [Tree('VBG', ['neighboring']), Tree('NNP', ['Mozambique'])])])])])])])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['church']), Tree('NN', ['spokesman'])]), Tree('VP', [Tree('VBD', ['said']), Tree('NP-TMP', [Tree('NN', ['today'])])]), Tree('.', ['.'])])])
# 4
# 'AID = 23449664'
# 'Code = 1711'
# 'Text = For example , the famous Benin bronzes were seized by British forces during a punitive raid in 1897 ; Nigeria has long sought their restitution .'
# Tree('ROOT', [Tree('S', [Tree('S', [Tree('PP', [Tree('IN', ['For']), Tree('NP', [Tree('NN', ['example'])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['famous']), Tree('NNP', ['Benin']), Tree('NNS', ['bronzes'])]), Tree('VP', [Tree('VBD', ['were']), Tree('VP', [Tree('VBN', ['seized']), Tree('PP', [Tree('IN', ['by']), Tree('NP', [Tree('JJ', ['British']), Tree('NNS', ['forces'])])]), Tree('PP', [Tree('IN', ['during']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['punitive']), Tree('NN', ['raid'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1897'])])])])])])])]), Tree(':', [';']), Tree('S', [Tree('NP', [Tree('NNP', ['Nigeria'])]), Tree('VP', [Tree('VBZ', ['has']), Tree('ADVP', [Tree('RB', ['long'])]), Tree('VP', [Tree('VBN', ['sought']), Tree('NP', [Tree('PRP$', ['their']), Tree('NN', ['restitution'])])])])]), Tree('.', ['.'])])])
# 5

# %%
import sys

# %%
sys.executable
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8'
